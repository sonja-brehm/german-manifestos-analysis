# %% [markdown]
# ### Sources
# **Unless otherwise stated, the code in this notebook is from "NLP Week 2.2 Lecture" and "NLP Week 2.2 Task".** Other sources, or when I wrote the code myself (or modified it), are marked with **##** at the beginning of the corresponding cell.
#
# #### Citation for the Hanover Tagger used in this notebook:
# For a explanation of the underlying ideas see: Christian Wartena (2019). A Probabilistic Morphology Model for German Lemmatization. In: Proceedings of the 15th Conference on Natural Language Processing (KONVENS 2019): Long Papers. Pp. 40-49, Erlangen. https://corpora.linguistik.uni-erlangen.de/data/konvens/proceedings/papers/KONVENS2019_paper_10.pdf https://doi.org/10.25968/opus-1527
#
# #### Stopword List from:
# https://github.com/solariz/german_stopwords
#
# Marco Götze and Steffen Geyer (2016), Source and more Information: https://solariz.de/de/downloads/6/german-enhanced-stopwords.htm
# ____

# %% [markdown]
# # Topic Modelling
# Note: The reasoning behind my choice of the topic numbers used here can be found in the 04.2_Topic-Numbers Notebook.
# I seperated it from this one to keep it a little easier to follow.

# %% [markdown]
# ### Preparation: Load data, define tokeniser

# %%
#Import all necessary packages
import numpy as np
import pandas as pd 
import re
import nltk
from HanTa import HanoverTagger as ht
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
from sklearn.decomposition import TruncatedSVD
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from nltk.tokenize.casual import casual_tokenize

# %%
#load in data
df = pd.read_csv('data/sorted_manifestos.csv', encoding='utf-8')

# %%
## I wrote the code in this cell

#add a column with party names
partyid_greens = [41111,41112,41113]
partyid_lefts = [41221, 41222, 41223]
partynames = []
#loop trough all indices of the dataset
for i in range(len(df)):
    #get the party ID of this index/row
    party_id = df.at[i, 'party']
    #add the corresponding party name
    if party_id in partyid_greens:
        partynames.append('Greens')
    elif party_id in partyid_lefts:
        partynames.append('Lefts')
    elif party_id == 41420:
        partynames.append('FDP')
    elif party_id == 41521:
        partynames.append('CDU')
    elif party_id == 41320:
        partynames.append('SPD')
    elif party_id == 41620:
        partynames.append('DP')
    elif party_id == 41953:
        partynames.append('AFD')

#add column with party names to df
df['partyname'] = partynames
#shorten the df
df = df[['date','partyname','text']]

# %%
## code in this cell is from the author NNK (2022), 'Pandas Combine Two Columns of Text in DataFrame'
## link: https://sparkbyexamples.com/pandas/pandas-combine-two-columns-of-text-in-dataframe/

#add a column that combines date and name, for easier access later
df["name & date"] = df['partyname'] +", "+ df["date"].astype(str)
df.sample(3)
# Out:
#       date partyname                                               text  \
# 42  195709       FDP   AKTIONSPROGRAMM 1957 Verkündet auf dem Wahlko...
# 19  202109     Lefts  Zeit zu handeln! Für soziale Sicherheit, Fried...
# 80  194908        DP  Programmpunkte der Deutschen Partei   1. Erneu...
#
#       name & date
# 42    FDP, 195709
# 19  Lefts, 202109
# 80     DP, 194908

# %%
## code in this cell is from GeeksForGeeks (2021), 'How to Read Text File Into List in Python?', Example 1
## link: https://www.geeksforgeeks.org/how-to-read-text-file-into-list-in-python/
## modified to read my data and split the text on spaces instead of dots

#open .txt file that contains the long stopword list
file_full = open('stopwords/german_stopwords/german_stopwords_full_edit.txt', "r")
data_full = file_full.read()

#create a list
german_stopwords_full = data_full.replace('\n', ' ').split(" ")

# %%
## I've modified this cell to use my lemmatiser and stopword list

tagger = ht.HanoverTagger('morphmodel_ger.pgz')

#create tokeniser
def my_tokeniser(doc):
    tokens = re.split(r'[\s.,;!?/"()#»«„“”:&–-]+', doc)
    #remove stopwords
    tokens_sw = [t for t in tokens if not t.lower() in german_stopwords_full and t != '']
    #lemmatiser
    tags = [tagger.analyze(word) for word in tokens_sw]
    tokens_sw_lemma = [lemma.lower() for (lemma,pos) in tags]
    return tokens_sw_lemma

# %% [markdown]
# ## LSA / SVD

# %%
#get TFIDF
tfidf_vectoriser = TfidfVectorizer(tokenizer=my_tokeniser)
tfidf = tfidf_vectoriser.fit_transform(df["text"])
#Save list of unique tokens (vocab) for later
vocab = tfidf_vectoriser.get_feature_names_out()
tfidf_df = pd.DataFrame(tfidf.todense(), columns = vocab)
print(tfidf.todense().shape)
# Out:
# (86, 55414)

# %%
#Subtract mean
tfidf_df = tfidf_df - tfidf_df.mean()

# %%
#How many topics?
num_topics = 6
pd.options.display.max_columns=num_topics
labels = ['topic{}'.format(i) for i in range(num_topics)]

# %%
#Calculate topics
svd = TruncatedSVD(n_components = num_topics, n_iter = 100) 
svd_topic_vectors = svd.fit_transform(tfidf_df.values)

# %%
#Most relevant tokens for each topic
topic_weights = pd.DataFrame(svd.components_.T, index=vocab, columns=labels)
num_terms = 20
for i in range(num_topics):
    print("___topic " + str(i) + "___")
    topicName = "topic" + str(i)
    weightedlist = topic_weights.get(topicName).sort_values()[-num_terms:]
    print(weightedlist.index.values)
# Out:
# ___topic 0___
# ['frau' 'unterstützen' 'nachhaltig' 'international' 'linke' 'öffentlich'
#  'kommune' 'schaffen' 'euro' 'ökologisch' 'europäisch' 'land'
#  'unternehmen' 'digital' 'kind' 'deutschland' 'grün' 'eu' 'mensch' 'stark']
# ___topic 1___
# ['schaffen' 'international' 'zusammenarbeit' 'cdu' 'wirtschaftlich'
#  'sozialdemokrat' 'aufgabe' 'fdp' 'arbeitsplatz' 'csu' 'spd' 'chance'
#  'ziel' 'land' 'staat' 'verbessern' 'europäisch' 'bürger' 'liberal'
#  'müssen']
# ___topic 2___
# ['solidarisch' 'mann' 'demokratisierung' 'ostdeutschland' 'bundesrepublik'
#  'gesellschaft' 'demokratisch' 'bündnis' 'ddr' 'gesellschaftlich' '90'
#  'brd' 'öffentlich' 'linke' 'frau' 'sozial' 'pds' 'ökologisch' 'grün'
#  'müssen']
# ___topic 3___
# ['regelung' 'individuell' 'schule' 'bildung' 'bürgergeld' 'privat'
#  'staatlich' 'staat' 'einzeln' 'europäisch' 'digital' 'euro' 'wettbewerb'
#  'für' 'afd' 'müssen' 'eu' 'fdp' 'demokrat' 'liberal']
# ___topic 4___
# ['abrüstungsschritt' 'mädchen' 'international' 'gesellschaftsvertrag'
#  'natur' 'umwelt' 'welt' 'deutsch' 'leben' 'volk' 'produkt' 'dritter'
#  'mann' '…' 'müssen' 'bündnis' 'frau' 'ökologisch' '90' 'grün']
# ___topic 5___
# ['corona' '1972' 'pandemi' "'" 'zeit' 'vgl' 'beschäftigter' 'bürger*inn'
#  'volk' 'digitalisierung' 'ewg' 'spd' 'öffentlich' 'bundesregierung'
#  'linke' 'müssen' 'sozialdemokrat' 'sozialdemokratisch' 'digital'
#  'demokrat']

# %% [markdown]
# **Translation of topics:**
#
#     ___topic 0___
#     ['woman' 'support' 'sustainable' 'international' 'left' 'public' 'commune' 'create' 'euro' 'ecological'
#     'european' 'country' 'company' 'digital' 'child' 'germany' 'green' 'eu' 'human' 'strong']
#     ___topic 1___
#     ['create' 'international' 'cooperation' 'cdu' 'economic' 'social democrat' 'task' 'fdp' 'job' 'csu'
#     'spd' 'opportunity' 'goal' 'country' 'state' 'improve' 'european' 'citizen' 'liberal 'must']
#     ___topic 2___
#     ['solidarity' 'man' 'democratisation' 'east germany' 'federal republic' 'society' 'democratic'
#     'alliance' 'gdr' 'social' '90' 'frg' 'public' 'left' 'woman' 'social' 'pds' 'ecological' 'green' 'must']
#     ___topic 3___
#     ['regulation' 'individual' 'school' 'education' 'basic income scheme' 'private' 'state' 'single/individual'
#     'european' 'digital' 'euro' 'competition' 'for' 'afd' 'must' 'eu' 'fdp' 'democrat' 'liberal']
#     ___topic 4___
#     ['disarmament step' 'girl' 'international' 'deed of association' 'nature' 'environment' 'world' 'german'
#     'life' 'people' 'product' 'third' 'man' '...' 'must' 'alliance' 'woman' 'ecological' '90' 'green']
#     ___topic 5___
#     ['corona' '1972' 'pandemic' ''' 'time' 'cf' 'employee' 'citizen' 'people/folk' 'digitalisation' 'eec' 'spd'
#     'public' 'federal government' 'left' 'must' 'social democrat' 'social democratic' 'digital' 'democrat']

# %%
## I wrote the code in this cell

#get all indices for the different parties
greens = [df.loc[i, 'name & date'] for i in range(len(df)) if df.loc[i, 'partyname'] == 'Greens']
lefts = [df.loc[i, 'name & date'] for i in range(len(df)) if df.loc[i, 'partyname'] == 'Lefts']
spd = [df.loc[i, 'name & date'] for i in range(len(df)) if df.loc[i, 'partyname'] == 'SPD']
fdp = [df.loc[i, 'name & date'] for i in range(len(df)) if df.loc[i, 'partyname'] == 'FDP']
cdu = [df.loc[i, 'name & date'] for i in range(len(df)) if df.loc[i, 'partyname'] == 'CDU']
afd = [df.loc[i, 'name & date'] for i in range(len(df)) if df.loc[i, 'partyname'] == 'AFD']
dp = [df.loc[i, 'name & date'] for i in range(len(df)) if df.loc[i, 'partyname'] == 'DP']

# %%
## code in this cell is from kanoki (2019), 'Color Columns, Rows & Cells of Pandas Dataframe'
## link: https://kanoki.org/2019/01/02/pandas-trick-for-the-day-color-code-columns-rows-cells-of-dataframe/

#function to highlight all values over 0.09
def color(val):
    color = 'peachpuff' if val > 0.1 else '0'
    return 'background-color: %s' % color

# %%
#How much does each topic apply to each manifesto of the CDU?
names = [t for t in df["name & date"]]
svd_topic_vectors_df = pd.DataFrame(svd_topic_vectors, columns=labels, index = names)
svd_topic_vectors_df.loc[cdu].style.applymap(color)
# Out:
# <style type="text/css">
# #T_c7746_row0_col0, #T_c7746_row0_col1, #T_c7746_row0_col2, #T_c7746_row0_col3, #T_c7746_row0_col4, #T_c7746_row1_col0, #T_c7746_row1_col1, #T_c7746_row1_col2, #T_c7746_row1_col3, #T_c7746_row1_col4, #T_c7746_row1_col5, #T_c7746_row2_col0, #T_c7746_row2_col1, #T_c7746_row2_col2, #T_c7746_row2_col3, #T_c7746_row2_col4, #T_c7746_row2_col5, #T_c7746_row3_col0, #T_c7746_row3_col1, #T_c7746_row3_col2, #T_c7746_row3_col3, #T_c7746_row3_col4, #T_c7746_row3_col5, #T_c7746_row4_col0, #T_c7746_row4_col1, #T_c7746_row4_col2, #T_c7746_row4_col3, #T_c7746_row4_col4, #T_c7746_row4_col5, #T_c7746_row5_col0, #T_c7746_row5_col1, #T_c7746_row5_col2, #T_c7746_row5_col3, #T_c7746_row5_col4, #T_c7746_row5_col5, #T_c7746_row6_col0, #T_c7746_row6_col2, #T_c7746_row6_col3, #T_c7746_row6_col4, #T_c7746_row6_col5, #T_c7746_row7_col0, #T_c7746_row7_col2, #T_c7746_row7_col3, #T_c7746_row7_col4, #T_c7746_row7_col5, #T_c7746_row8_col0, #T_c7746_row8_col2, #T_c7746_row8_col3, #T_c7746_row8_col4, #T_c7746_row8_col5, #T_c7746_row9_col0, #T_c7746_row9_col1, #T_c7746_row9_col2, #T_c7746_row9_col3, #T_c7746_row9_col4, #T_c7746_row9_col5, #T_c7746_row10_col0, #T_c7746_row10_col2, #T_c7746_row10_col3, #T_c7746_row10_col4, #T_c7746_row10_col5, #T_c7746_row11_col0, #T_c7746_row11_col2, #T_c7746_row11_col3, #T_c7746_row11_col4, #T_c7746_row11_col5, #T_c7746_row12_col0, #T_c7746_row12_col2, #T_c7746_row12_col3, #T_c7746_row12_col4, #T_c7746_row12_col5, #T_c7746_row13_col0, #T_c7746_row13_col2, #T_c7746_row13_col3, #T_c7746_row13_col4, #T_c7746_row13_col5, #T_c7746_row14_col1, #T_c7746_row14_col2, #T_c7746_row14_col3, #T_c7746_row14_col4, #T_c7746_row14_col5, #T_c7746_row15_col1, #T_c7746_row15_col2, #T_c7746_row15_col3, #T_c7746_row15_col4, #T_c7746_row15_col5, #T_c7746_row16_col1, #T_c7746_row16_col2, #T_c7746_row16_col3, #T_c7746_row16_col4, #T_c7746_row16_col5, #T_c7746_row17_col1, #T_c7746_row17_col2, #T_c7746_row17_col3, #T_c7746_row17_col4, #T_c7746_row17_col5, #T_c7746_row18_col1, #T_c7746_row18_col2, #T_c7746_row18_col3, #T_c7746_row18_col4, #T_c7746_row18_col5, #T_c7746_row19_col1, #T_c7746_row19_col2, #T_c7746_row19_col3, #T_c7746_row19_col4 {
#   background-color: 0;
# }
# #T_c7746_row0_col5, #T_c7746_row6_col1, #T_c7746_row7_col1, #T_c7746_row8_col1, #T_c7746_row10_col1, #T_c7746_row11_col1, #T_c7746_row12_col1, #T_c7746_row13_col1, #T_c7746_row14_col0, #T_c7746_row15_col0, #T_c7746_row16_col0, #T_c7746_row17_col0, #T_c7746_row18_col0, #T_c7746_row19_col0, #T_c7746_row19_col5 {
#   background-color: peachpuff;
# }
# </style>
# <table id="T_c7746">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c7746_level0_col0" class="col_heading level0 col0" >topic0</th>
#       <th id="T_c7746_level0_col1" class="col_heading level0 col1" >topic1</th>
#       <th id="T_c7746_level0_col2" class="col_heading level0 col2" >topic2</th>
#       <th id="T_c7746_level0_col3" class="col_heading level0 col3" >topic3</th>
#       <th id="T_c7746_level0_col4" class="col_heading level0 col4" >topic4</th>
#       <th id="T_c7746_level0_col5" class="col_heading level0 col5" >topic5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7746_level0_row0" class="row_heading level0 row0" >CDU, 194908</th>
#       <td id="T_c7746_row0_col0" class="data row0 col0" >-0.309774</td>
#       <td id="T_c7746_row0_col1" class="data row0 col1" >-0.042604</td>
#       <td id="T_c7746_row0_col2" class="data row0 col2" >0.013607</td>
#       <td id="T_c7746_row0_col3" class="data row0 col3" >0.017922</td>
#       <td id="T_c7746_row0_col4" class="data row0 col4" >0.008894</td>
#       <td id="T_c7746_row0_col5" class="data row0 col5" >0.106317</td>
#     </tr>
#     <tr>
#       <th id="T_c7746_level0_row1" class="row_heading level0 row1" >CDU, 195309</th>
#       <td id="T_c7746_row1_col0" class="data row1 col0" >-0.360817</td>
#       <td id="T_c7746_row1_col1" class="data row1 col1" >-0.069148</td>
#       <td id="T_c7746_row1_col2" class="data row1 col2" >-0.055315</td>
#       <td id="T_c7746_row1_col3" class="data row1 col3" >-0.022354</td>
#       <td id="T_c7746_row1_col4" class="data row1 col4" >0.010620</td>
#       <td id="T_c7746_row1_col5" class="data row1 col5" >0.052857</td>
#     </tr>
#     <tr>
#       <th id="T_c7746_level0_row2" class="row_heading level0 row2" >CDU, 195709</th>
#       <td id="T_c7746_row2_col0" class="data row2 col0" >-0.374518</td>
#       <td id="T_c7746_row2_col1" class="data row2 col1" >-0.305102</td>
#       <td id="T_c7746_row2_col2" class="data row2 col2" >-0.204080</td>
#       <td id="T_c7746_row2_col3" class="data row2 col3" >-0.100667</td>
#       <td id="T_c7746_row2_col4" class="data row2 col4" >0.044893</td>
#       <td id="T_c7746_row2_col5" class="data row2 col5" >-0.165958</td>
#     </tr>
#     <tr>
#       <th id="T_c7746_level0_row3" class="row_heading level0 row3" >CDU, 196109</th>
#       <td id="T_c7746_row3_col0" class="data row3 col0" >-0.314959</td>
#       <td id="T_c7746_row3_col1" class="data row3 col1" >-0.298721</td>
#       <td id="T_c7746_row3_col2" class="data row3 col2" >-0.188831</td>
#       <td id="T_c7746_row3_col3" class="data row3 col3" >-0.058389</td>
#       <td id="T_c7746_row3_col4" class="data row3 col4" >0.047358</td>
#       <td id="T_c7746_row3_col5" class="data row3 col5" >-0.142975</td>
#     </tr>
#     <tr>
#       <th id="T_c7746_level0_row4" class="row_heading level0 row4" >CDU, 196509</th>
#       <td id="T_c7746_row4_col0" class="data row4 col0" >-0.261657</td>
#       <td id="T_c7746_row4_col1" class="data row4 col1" >-0.053693</td>
#       <td id="T_c7746_row4_col2" class="data row4 col2" >-0.208686</td>
#       <td id="T_c7746_row4_col3" class="data row4 col3" >-0.313375</td>
#       <td id="T_c7746_row4_col4" class="data row4 col4" >0.027896</td>
#       <td id="T_c7746_row4_col5" class="data row4 col5" >-0.088420</td>
#     </tr>
#     <tr>
#       <th id="T_c7746_level0_row5" class="row_heading level0 row5" >CDU, 196909</th>
#       <td id="T_c7746_row5_col0" class="data row5 col0" >-0.270940</td>
#       <td id="T_c7746_row5_col1" class="data row5 col1" >0.080388</td>
#       <td id="T_c7746_row5_col2" class="data row5 col2" >-0.043406</td>
#       <td id="T_c7746_row5_col3" class="data row5 col3" >-0.054807</td>
#       <td id="T_c7746_row5_col4" class="data row5 col4" >0.002368</td>
#       <td id="T_c7746_row5_col5" class="data row5 col5" >0.083322</td>
#     </tr>
#     <tr>
#       <th id="T_c7746_level0_row6" class="row_heading level0 row6" >CDU, 197211</th>
#       <td id="T_c7746_row6_col0" class="data row6 col0" >-0.230471</td>
#       <td id="T_c7746_row6_col1" class="data row6 col1" >0.143681</td>
#       <td id="T_c7746_row6_col2" class="data row6 col2" >0.028214</td>
#       <td id="T_c7746_row6_col3" class="data row6 col3" >-0.073892</td>
#       <td id="T_c7746_row6_col4" class="data row6 col4" >-0.053329</td>
#       <td id="T_c7746_row6_col5" class="data row6 col5" >0.089838</td>
#     </tr>
#     <tr>
#       <th id="T_c7746_level0_row7" class="row_heading level0 row7" >CDU, 197610</th>
#       <td id="T_c7746_row7_col0" class="data row7 col0" >-0.109763</td>
#       <td id="T_c7746_row7_col1" class="data row7 col1" >0.159873</td>
#       <td id="T_c7746_row7_col2" class="data row7 col2" >-0.044590</td>
#       <td id="T_c7746_row7_col3" class="data row7 col3" >-0.155112</td>
#       <td id="T_c7746_row7_col4" class="data row7 col4" >-0.087067</td>
#       <td id="T_c7746_row7_col5" class="data row7 col5" >-0.005860</td>
#     </tr>
#     <tr>
#       <th id="T_c7746_level0_row8" class="row_heading level0 row8" >CDU, 198010</th>
#       <td id="T_c7746_row8_col0" class="data row8 col0" >-0.123987</td>
#       <td id="T_c7746_row8_col1" class="data row8 col1" >0.118223</td>
#       <td id="T_c7746_row8_col2" class="data row8 col2" >-0.069966</td>
#       <td id="T_c7746_row8_col3" class="data row8 col3" >-0.202230</td>
#       <td id="T_c7746_row8_col4" class="data row8 col4" >-0.034885</td>
#       <td id="T_c7746_row8_col5" class="data row8 col5" >-0.078487</td>
#     </tr>
#     <tr>
#       <th id="T_c7746_level0_row9" c

# %%
#How much does each topic apply to each manifesto of the SPD?
svd_topic_vectors_df.loc[spd].style.applymap(color)
# Out:
# <style type="text/css">
# #T_911de_row0_col0, #T_911de_row0_col1, #T_911de_row0_col2, #T_911de_row0_col3, #T_911de_row0_col4, #T_911de_row0_col5, #T_911de_row1_col0, #T_911de_row1_col1, #T_911de_row1_col2, #T_911de_row1_col3, #T_911de_row1_col4, #T_911de_row2_col0, #T_911de_row2_col1, #T_911de_row2_col2, #T_911de_row2_col3, #T_911de_row2_col4, #T_911de_row2_col5, #T_911de_row3_col0, #T_911de_row3_col1, #T_911de_row3_col2, #T_911de_row3_col3, #T_911de_row3_col4, #T_911de_row4_col0, #T_911de_row4_col1, #T_911de_row4_col2, #T_911de_row4_col3, #T_911de_row4_col4, #T_911de_row5_col0, #T_911de_row5_col2, #T_911de_row5_col3, #T_911de_row5_col4, #T_911de_row6_col0, #T_911de_row6_col1, #T_911de_row6_col2, #T_911de_row6_col3, #T_911de_row6_col4, #T_911de_row7_col0, #T_911de_row7_col2, #T_911de_row7_col3, #T_911de_row7_col4, #T_911de_row8_col0, #T_911de_row8_col3, #T_911de_row8_col4, #T_911de_row9_col0, #T_911de_row9_col3, #T_911de_row9_col4, #T_911de_row10_col0, #T_911de_row10_col3, #T_911de_row10_col4, #T_911de_row11_col0, #T_911de_row11_col1, #T_911de_row11_col3, #T_911de_row11_col4, #T_911de_row11_col5, #T_911de_row12_col0, #T_911de_row12_col3, #T_911de_row12_col4, #T_911de_row12_col5, #T_911de_row13_col0, #T_911de_row13_col2, #T_911de_row13_col3, #T_911de_row13_col4, #T_911de_row13_col5, #T_911de_row14_col1, #T_911de_row14_col2, #T_911de_row14_col3, #T_911de_row14_col4, #T_911de_row14_col5, #T_911de_row15_col1, #T_911de_row15_col2, #T_911de_row15_col3, #T_911de_row15_col4, #T_911de_row15_col5, #T_911de_row16_col1, #T_911de_row16_col2, #T_911de_row16_col3, #T_911de_row16_col4, #T_911de_row16_col5, #T_911de_row17_col1, #T_911de_row17_col2, #T_911de_row17_col3, #T_911de_row17_col4, #T_911de_row17_col5, #T_911de_row18_col1, #T_911de_row18_col2, #T_911de_row18_col3, #T_911de_row18_col4, #T_911de_row19_col1, #T_911de_row19_col2, #T_911de_row19_col3, #T_911de_row19_col4 {
#   background-color: 0;
# }
# #T_911de_row1_col5, #T_911de_row3_col5, #T_911de_row4_col5, #T_911de_row5_col1, #T_911de_row5_col5, #T_911de_row6_col5, #T_911de_row7_col1, #T_911de_row7_col5, #T_911de_row8_col1, #T_911de_row8_col2, #T_911de_row8_col5, #T_911de_row9_col1, #T_911de_row9_col2, #T_911de_row9_col5, #T_911de_row10_col1, #T_911de_row10_col2, #T_911de_row10_col5, #T_911de_row11_col2, #T_911de_row12_col1, #T_911de_row12_col2, #T_911de_row13_col1, #T_911de_row14_col0, #T_911de_row15_col0, #T_911de_row16_col0, #T_911de_row17_col0, #T_911de_row18_col0, #T_911de_row18_col5, #T_911de_row19_col0, #T_911de_row19_col5 {
#   background-color: peachpuff;
# }
# </style>
# <table id="T_911de">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_911de_level0_col0" class="col_heading level0 col0" >topic0</th>
#       <th id="T_911de_level0_col1" class="col_heading level0 col1" >topic1</th>
#       <th id="T_911de_level0_col2" class="col_heading level0 col2" >topic2</th>
#       <th id="T_911de_level0_col3" class="col_heading level0 col3" >topic3</th>
#       <th id="T_911de_level0_col4" class="col_heading level0 col4" >topic4</th>
#       <th id="T_911de_level0_col5" class="col_heading level0 col5" >topic5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_911de_level0_row0" class="row_heading level0 row0" >SPD, 194908</th>
#       <td id="T_911de_row0_col0" class="data row0 col0" >-0.278067</td>
#       <td id="T_911de_row0_col1" class="data row0 col1" >-0.255175</td>
#       <td id="T_911de_row0_col2" class="data row0 col2" >-0.100378</td>
#       <td id="T_911de_row0_col3" class="data row0 col3" >-0.030470</td>
#       <td id="T_911de_row0_col4" class="data row0 col4" >0.058436</td>
#       <td id="T_911de_row0_col5" class="data row0 col5" >0.030341</td>
#     </tr>
#     <tr>
#       <th id="T_911de_level0_row1" class="row_heading level0 row1" >SPD, 195309</th>
#       <td id="T_911de_row1_col0" class="data row1 col0" >-0.274200</td>
#       <td id="T_911de_row1_col1" class="data row1 col1" >-0.187717</td>
#       <td id="T_911de_row1_col2" class="data row1 col2" >-0.026855</td>
#       <td id="T_911de_row1_col3" class="data row1 col3" >-0.038405</td>
#       <td id="T_911de_row1_col4" class="data row1 col4" >0.033514</td>
#       <td id="T_911de_row1_col5" class="data row1 col5" >0.101135</td>
#     </tr>
#     <tr>
#       <th id="T_911de_level0_row2" class="row_heading level0 row2" >SPD, 195709</th>
#       <td id="T_911de_row2_col0" class="data row2 col0" >-0.269870</td>
#       <td id="T_911de_row2_col1" class="data row2 col1" >-0.040947</td>
#       <td id="T_911de_row2_col2" class="data row2 col2" >-0.095069</td>
#       <td id="T_911de_row2_col3" class="data row2 col3" >-0.132273</td>
#       <td id="T_911de_row2_col4" class="data row2 col4" >-0.005639</td>
#       <td id="T_911de_row2_col5" class="data row2 col5" >0.066374</td>
#     </tr>
#     <tr>
#       <th id="T_911de_level0_row3" class="row_heading level0 row3" >SPD, 196109</th>
#       <td id="T_911de_row3_col0" class="data row3 col0" >-0.301698</td>
#       <td id="T_911de_row3_col1" class="data row3 col1" >-0.068778</td>
#       <td id="T_911de_row3_col2" class="data row3 col2" >-0.060421</td>
#       <td id="T_911de_row3_col3" class="data row3 col3" >-0.110602</td>
#       <td id="T_911de_row3_col4" class="data row3 col4" >0.042954</td>
#       <td id="T_911de_row3_col5" class="data row3 col5" >0.173813</td>
#     </tr>
#     <tr>
#       <th id="T_911de_level0_row4" class="row_heading level0 row4" >SPD, 196509</th>
#       <td id="T_911de_row4_col0" class="data row4 col0" >-0.235024</td>
#       <td id="T_911de_row4_col1" class="data row4 col1" >0.060695</td>
#       <td id="T_911de_row4_col2" class="data row4 col2" >-0.047813</td>
#       <td id="T_911de_row4_col3" class="data row4 col3" >-0.089604</td>
#       <td id="T_911de_row4_col4" class="data row4 col4" >-0.008214</td>
#       <td id="T_911de_row4_col5" class="data row4 col5" >0.230121</td>
#     </tr>
#     <tr>
#       <th id="T_911de_level0_row5" class="row_heading level0 row5" >SPD, 196909</th>
#       <td id="T_911de_row5_col0" class="data row5 col0" >-0.273943</td>
#       <td id="T_911de_row5_col1" class="data row5 col1" >0.167700</td>
#       <td id="T_911de_row5_col2" class="data row5 col2" >0.034969</td>
#       <td id="T_911de_row5_col3" class="data row5 col3" >-0.166740</td>
#       <td id="T_911de_row5_col4" class="data row5 col4" >-0.077790</td>
#       <td id="T_911de_row5_col5" class="data row5 col5" >0.203965</td>
#     </tr>
#     <tr>
#       <th id="T_911de_level0_row6" class="row_heading level0 row6" >SPD, 197211</th>
#       <td id="T_911de_row6_col0" class="data row6 col0" >-0.164216</td>
#       <td id="T_911de_row6_col1" class="data row6 col1" >0.087404</td>
#       <td id="T_911de_row6_col2" class="data row6 col2" >0.030428</td>
#       <td id="T_911de_row6_col3" class="data row6 col3" >-0.115895</td>
#       <td id="T_911de_row6_col4" class="data row6 col4" >-0.120974</td>
#       <td id="T_911de_row6_col5" class="data row6 col5" >0.150265</td>
#     </tr>
#     <tr>
#       <th id="T_911de_level0_row7" class="row_heading level0 row7" >SPD, 197610</th>
#       <td id="T_911de_row7_col0" class="data row7 col0" >-0.158990</td>
#       <td id="T_911de_row7_col1" class="data row7 col1" >0.156700</td>
#       <td id="T_911de_row7_col2" class="data row7 col2" >0.028716</td>
#       <td id="T_911de_row7_col3" class="data row7 col3" >-0.238610</td>
#       <td id="T_911de_row7_col4" class="data row7 col4" >-0.127035</td>
#       <td id="T_911de_row7_col5" class="data row7 col5" >0.167826</td>
#     </tr>
#     <tr>
#       <th id="T_911de_level0_row8" class="row_heading level0 row8" >SPD, 198010</th>
#       <td id="T_911de_row8_col0" class="data row8 col0" >-0.130621</td>
#       <td id="T_911de_row8_col1" class="data row8 col1" >0.221173</td>
#       <td id="T_911de_row8_col2" class="data row8 col2" >0.115848</td>
#       <td id="T_911de_row8_col3" class="data row8 col3" >-0.211313</td>
#       <td id="T_911de_row8_col4" class="data row8 col4" >-0.059037</td>
#       <td id="T_911de_row8_col5" class="data row8 col5" >0.157176</td>
#     </tr>
#     <tr>
#       <th id="T_911de_level0_row9" class

# %%
svd_topic_vectors_df.loc[fdp].style.applymap(color)
# Out:
# <style type="text/css">
# #T_62b99_row0_col0, #T_62b99_row0_col1, #T_62b99_row0_col2, #T_62b99_row0_col3, #T_62b99_row0_col4, #T_62b99_row0_col5, #T_62b99_row1_col0, #T_62b99_row1_col1, #T_62b99_row1_col2, #T_62b99_row1_col4, #T_62b99_row1_col5, #T_62b99_row2_col0, #T_62b99_row2_col1, #T_62b99_row2_col2, #T_62b99_row2_col3, #T_62b99_row2_col4, #T_62b99_row2_col5, #T_62b99_row3_col0, #T_62b99_row3_col1, #T_62b99_row3_col2, #T_62b99_row3_col4, #T_62b99_row4_col0, #T_62b99_row4_col2, #T_62b99_row4_col4, #T_62b99_row4_col5, #T_62b99_row5_col0, #T_62b99_row5_col2, #T_62b99_row5_col4, #T_62b99_row6_col0, #T_62b99_row6_col1, #T_62b99_row6_col2, #T_62b99_row6_col4, #T_62b99_row6_col5, #T_62b99_row7_col0, #T_62b99_row7_col2, #T_62b99_row7_col4, #T_62b99_row7_col5, #T_62b99_row8_col0, #T_62b99_row8_col4, #T_62b99_row8_col5, #T_62b99_row9_col0, #T_62b99_row9_col4, #T_62b99_row9_col5, #T_62b99_row10_col0, #T_62b99_row10_col2, #T_62b99_row10_col4, #T_62b99_row10_col5, #T_62b99_row11_col0, #T_62b99_row11_col4, #T_62b99_row11_col5, #T_62b99_row12_col0, #T_62b99_row12_col4, #T_62b99_row12_col5, #T_62b99_row13_col0, #T_62b99_row13_col2, #T_62b99_row13_col4, #T_62b99_row13_col5, #T_62b99_row14_col2, #T_62b99_row14_col4, #T_62b99_row14_col5, #T_62b99_row15_col0, #T_62b99_row15_col2, #T_62b99_row15_col4, #T_62b99_row15_col5, #T_62b99_row16_col1, #T_62b99_row16_col2, #T_62b99_row16_col4, #T_62b99_row16_col5, #T_62b99_row17_col2, #T_62b99_row17_col4, #T_62b99_row17_col5, #T_62b99_row18_col1, #T_62b99_row18_col2, #T_62b99_row18_col4, #T_62b99_row19_col1, #T_62b99_row19_col2, #T_62b99_row19_col4 {
#   background-color: 0;
# }
# #T_62b99_row1_col3, #T_62b99_row3_col3, #T_62b99_row3_col5, #T_62b99_row4_col1, #T_62b99_row4_col3, #T_62b99_row5_col1, #T_62b99_row5_col3, #T_62b99_row5_col5, #T_62b99_row6_col3, #T_62b99_row7_col1, #T_62b99_row7_col3, #T_62b99_row8_col1, #T_62b99_row8_col2, #T_62b99_row8_col3, #T_62b99_row9_col1, #T_62b99_row9_col2, #T_62b99_row9_col3, #T_62b99_row10_col1, #T_62b99_row10_col3, #T_62b99_row11_col1, #T_62b99_row11_col2, #T_62b99_row11_col3, #T_62b99_row12_col1, #T_62b99_row12_col2, #T_62b99_row12_col3, #T_62b99_row13_col1, #T_62b99_row13_col3, #T_62b99_row14_col0, #T_62b99_row14_col1, #T_62b99_row14_col3, #T_62b99_row15_col1, #T_62b99_row15_col3, #T_62b99_row16_col0, #T_62b99_row16_col3, #T_62b99_row17_col0, #T_62b99_row17_col1, #T_62b99_row17_col3, #T_62b99_row18_col0, #T_62b99_row18_col3, #T_62b99_row18_col5, #T_62b99_row19_col0, #T_62b99_row19_col3, #T_62b99_row19_col5 {
#   background-color: peachpuff;
# }
# </style>
# <table id="T_62b99">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_62b99_level0_col0" class="col_heading level0 col0" >topic0</th>
#       <th id="T_62b99_level0_col1" class="col_heading level0 col1" >topic1</th>
#       <th id="T_62b99_level0_col2" class="col_heading level0 col2" >topic2</th>
#       <th id="T_62b99_level0_col3" class="col_heading level0 col3" >topic3</th>
#       <th id="T_62b99_level0_col4" class="col_heading level0 col4" >topic4</th>
#       <th id="T_62b99_level0_col5" class="col_heading level0 col5" >topic5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_62b99_level0_row0" class="row_heading level0 row0" >FDP, 194908</th>
#       <td id="T_62b99_row0_col0" class="data row0 col0" >-0.332290</td>
#       <td id="T_62b99_row0_col1" class="data row0 col1" >-0.229810</td>
#       <td id="T_62b99_row0_col2" class="data row0 col2" >-0.077193</td>
#       <td id="T_62b99_row0_col3" class="data row0 col3" >0.081672</td>
#       <td id="T_62b99_row0_col4" class="data row0 col4" >0.059958</td>
#       <td id="T_62b99_row0_col5" class="data row0 col5" >0.014327</td>
#     </tr>
#     <tr>
#       <th id="T_62b99_level0_row1" class="row_heading level0 row1" >FDP, 195309</th>
#       <td id="T_62b99_row1_col0" class="data row1 col0" >-0.331092</td>
#       <td id="T_62b99_row1_col1" class="data row1 col1" >-0.182736</td>
#       <td id="T_62b99_row1_col2" class="data row1 col2" >-0.118707</td>
#       <td id="T_62b99_row1_col3" class="data row1 col3" >0.160474</td>
#       <td id="T_62b99_row1_col4" class="data row1 col4" >0.018487</td>
#       <td id="T_62b99_row1_col5" class="data row1 col5" >-0.157575</td>
#     </tr>
#     <tr>
#       <th id="T_62b99_level0_row2" class="row_heading level0 row2" >FDP, 195709</th>
#       <td id="T_62b99_row2_col0" class="data row2 col0" >-0.337953</td>
#       <td id="T_62b99_row2_col1" class="data row2 col1" >-0.199455</td>
#       <td id="T_62b99_row2_col2" class="data row2 col2" >-0.106743</td>
#       <td id="T_62b99_row2_col3" class="data row2 col3" >-0.015281</td>
#       <td id="T_62b99_row2_col4" class="data row2 col4" >0.052512</td>
#       <td id="T_62b99_row2_col5" class="data row2 col5" >-0.064256</td>
#     </tr>
#     <tr>
#       <th id="T_62b99_level0_row3" class="row_heading level0 row3" >FDP, 196109</th>
#       <td id="T_62b99_row3_col0" class="data row3 col0" >-0.320290</td>
#       <td id="T_62b99_row3_col1" class="data row3 col1" >-0.047746</td>
#       <td id="T_62b99_row3_col2" class="data row3 col2" >-0.052808</td>
#       <td id="T_62b99_row3_col3" class="data row3 col3" >0.137762</td>
#       <td id="T_62b99_row3_col4" class="data row3 col4" >0.007917</td>
#       <td id="T_62b99_row3_col5" class="data row3 col5" >0.175957</td>
#     </tr>
#     <tr>
#       <th id="T_62b99_level0_row4" class="row_heading level0 row4" >FDP, 196509</th>
#       <td id="T_62b99_row4_col0" class="data row4 col0" >-0.320356</td>
#       <td id="T_62b99_row4_col1" class="data row4 col1" >0.113735</td>
#       <td id="T_62b99_row4_col2" class="data row4 col2" >0.051453</td>
#       <td id="T_62b99_row4_col3" class="data row4 col3" >0.194845</td>
#       <td id="T_62b99_row4_col4" class="data row4 col4" >-0.001209</td>
#       <td id="T_62b99_row4_col5" class="data row4 col5" >0.096786</td>
#     </tr>
#     <tr>
#       <th id="T_62b99_level0_row5" class="row_heading level0 row5" >FDP, 196909</th>
#       <td id="T_62b99_row5_col0" class="data row5 col0" >-0.274353</td>
#       <td id="T_62b99_row5_col1" class="data row5 col1" >0.172840</td>
#       <td id="T_62b99_row5_col2" class="data row5 col2" >0.093031</td>
#       <td id="T_62b99_row5_col3" class="data row5 col3" >0.134064</td>
#       <td id="T_62b99_row5_col4" class="data row5 col4" >-0.032272</td>
#       <td id="T_62b99_row5_col5" class="data row5 col5" >0.129315</td>
#     </tr>
#     <tr>
#       <th id="T_62b99_level0_row6" class="row_heading level0 row6" >FDP, 197211</th>
#       <td id="T_62b99_row6_col0" class="data row6 col0" >-0.266167</td>
#       <td id="T_62b99_row6_col1" class="data row6 col1" >-0.031976</td>
#       <td id="T_62b99_row6_col2" class="data row6 col2" >-0.092037</td>
#       <td id="T_62b99_row6_col3" class="data row6 col3" >0.137904</td>
#       <td id="T_62b99_row6_col4" class="data row6 col4" >-0.060893</td>
#       <td id="T_62b99_row6_col5" class="data row6 col5" >-0.162677</td>
#     </tr>
#     <tr>
#       <th id="T_62b99_level0_row7" class="row_heading level0 row7" >FDP, 197610</th>
#       <td id="T_62b99_row7_col0" class="data row7 col0" >-0.213103</td>
#       <td id="T_62b99_row7_col1" class="data row7 col1" >0.350723</td>
#       <td id="T_62b99_row7_col2" class="data row7 col2" >0.085947</td>
#       <td id="T_62b99_row7_col3" class="data row7 col3" >0.210968</td>
#       <td id="T_62b99_row7_col4" class="data row7 col4" >-0.098484</td>
#       <td id="T_62b99_row7_col5" class="data row7 col5" >-0.007711</td>
#     </tr>
#     <tr>
#       <th id="T_62b99_level0_row8" class="row_heading level0 row8" >FDP, 198010</th>
#       <td id="T_62b99_row8_col0" class="data row8 col0" >-0.125114</td>
#       <td id="T_62b99_row8_col1" class="data row8 col1" >0.383492</td>
#       <td id="T_62b99_row8_col2" class="data row8 col2" >0.111909</td>
#       <td id="T_62b99_row8_col3" class="data row8 col3" >0.236229</td>
#       <td id="T_62b99_row8_col4" class="data row8 col4" >-0.045865</td>
#       <td id="T_62b99_row8_col5" class="data row8 col5" >0.059923</td>
#     </tr>
#     <tr>
#       <th id="T_62b99_level0_row9" class="ro

# %%
svd_topic_vectors_df.loc[greens].style.applymap(color)
# Out:
# <style type="text/css">
# #T_56274_row0_col0, #T_56274_row0_col1, #T_56274_row0_col3, #T_56274_row0_col5, #T_56274_row1_col0, #T_56274_row1_col1, #T_56274_row1_col3, #T_56274_row1_col5, #T_56274_row2_col0, #T_56274_row2_col1, #T_56274_row2_col3, #T_56274_row2_col5, #T_56274_row3_col0, #T_56274_row3_col1, #T_56274_row3_col3, #T_56274_row3_col5, #T_56274_row4_col0, #T_56274_row4_col1, #T_56274_row4_col3, #T_56274_row4_col5, #T_56274_row5_col1, #T_56274_row5_col3, #T_56274_row5_col5, #T_56274_row6_col1, #T_56274_row6_col2, #T_56274_row6_col3, #T_56274_row6_col5, #T_56274_row7_col1, #T_56274_row7_col3, #T_56274_row7_col5, #T_56274_row8_col1, #T_56274_row8_col2, #T_56274_row8_col3, #T_56274_row8_col5, #T_56274_row9_col1, #T_56274_row9_col2, #T_56274_row9_col3, #T_56274_row9_col5, #T_56274_row10_col1, #T_56274_row10_col2, #T_56274_row10_col3, #T_56274_row10_col4 {
#   background-color: 0;
# }
# #T_56274_row0_col2, #T_56274_row0_col4, #T_56274_row1_col2, #T_56274_row1_col4, #T_56274_row2_col2, #T_56274_row2_col4, #T_56274_row3_col2, #T_56274_row3_col4, #T_56274_row4_col2, #T_56274_row4_col4, #T_56274_row5_col0, #T_56274_row5_col2, #T_56274_row5_col4, #T_56274_row6_col0, #T_56274_row6_col4, #T_56274_row7_col0, #T_56274_row7_col2, #T_56274_row7_col4, #T_56274_row8_col0, #T_56274_row8_col4, #T_56274_row9_col0, #T_56274_row9_col4, #T_56274_row10_col0, #T_56274_row10_col5 {
#   background-color: peachpuff;
# }
# </style>
# <table id="T_56274">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_56274_level0_col0" class="col_heading level0 col0" >topic0</th>
#       <th id="T_56274_level0_col1" class="col_heading level0 col1" >topic1</th>
#       <th id="T_56274_level0_col2" class="col_heading level0 col2" >topic2</th>
#       <th id="T_56274_level0_col3" class="col_heading level0 col3" >topic3</th>
#       <th id="T_56274_level0_col4" class="col_heading level0 col4" >topic4</th>
#       <th id="T_56274_level0_col5" class="col_heading level0 col5" >topic5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_56274_level0_row0" class="row_heading level0 row0" >Greens, 198303</th>
#       <td id="T_56274_row0_col0" class="data row0 col0" >-0.144388</td>
#       <td id="T_56274_row0_col1" class="data row0 col1" >-0.201227</td>
#       <td id="T_56274_row0_col2" class="data row0 col2" >0.200227</td>
#       <td id="T_56274_row0_col3" class="data row0 col3" >-0.048468</td>
#       <td id="T_56274_row0_col4" class="data row0 col4" >0.231850</td>
#       <td id="T_56274_row0_col5" class="data row0 col5" >0.000838</td>
#     </tr>
#     <tr>
#       <th id="T_56274_level0_row1" class="row_heading level0 row1" >Greens, 198701</th>
#       <td id="T_56274_row1_col0" class="data row1 col0" >0.027523</td>
#       <td id="T_56274_row1_col1" class="data row1 col1" >-0.143053</td>
#       <td id="T_56274_row1_col2" class="data row1 col2" >0.410976</td>
#       <td id="T_56274_row1_col3" class="data row1 col3" >-0.026315</td>
#       <td id="T_56274_row1_col4" class="data row1 col4" >0.459437</td>
#       <td id="T_56274_row1_col5" class="data row1 col5" >-0.037855</td>
#     </tr>
#     <tr>
#       <th id="T_56274_level0_row2" class="row_heading level0 row2" >Greens, 199012</th>
#       <td id="T_56274_row2_col0" class="data row2 col0" >0.005579</td>
#       <td id="T_56274_row2_col1" class="data row2 col1" >-0.078876</td>
#       <td id="T_56274_row2_col2" class="data row2 col2" >0.485268</td>
#       <td id="T_56274_row2_col3" class="data row2 col3" >-0.028134</td>
#       <td id="T_56274_row2_col4" class="data row2 col4" >0.373659</td>
#       <td id="T_56274_row2_col5" class="data row2 col5" >-0.049975</td>
#     </tr>
#     <tr>
#       <th id="T_56274_level0_row3" class="row_heading level0 row3" >Greens, 199410</th>
#       <td id="T_56274_row3_col0" class="data row3 col0" >0.081024</td>
#       <td id="T_56274_row3_col1" class="data row3 col1" >0.059184</td>
#       <td id="T_56274_row3_col2" class="data row3 col2" >0.425998</td>
#       <td id="T_56274_row3_col3" class="data row3 col3" >-0.019562</td>
#       <td id="T_56274_row3_col4" class="data row3 col4" >0.282791</td>
#       <td id="T_56274_row3_col5" class="data row3 col5" >-0.010497</td>
#     </tr>
#     <tr>
#       <th id="T_56274_level0_row4" class="row_heading level0 row4" >Greens, 199809</th>
#       <td id="T_56274_row4_col0" class="data row4 col0" >0.092828</td>
#       <td id="T_56274_row4_col1" class="data row4 col1" >0.044607</td>
#       <td id="T_56274_row4_col2" class="data row4 col2" >0.377229</td>
#       <td id="T_56274_row4_col3" class="data row4 col3" >0.014761</td>
#       <td id="T_56274_row4_col4" class="data row4 col4" >0.396095</td>
#       <td id="T_56274_row4_col5" class="data row4 col5" >-0.024556</td>
#     </tr>
#     <tr>
#       <th id="T_56274_level0_row5" class="row_heading level0 row5" >Greens, 200209</th>
#       <td id="T_56274_row5_col0" class="data row5 col0" >0.343845</td>
#       <td id="T_56274_row5_col1" class="data row5 col1" >-0.014910</td>
#       <td id="T_56274_row5_col2" class="data row5 col2" >0.154193</td>
#       <td id="T_56274_row5_col3" class="data row5 col3" >-0.021318</td>
#       <td id="T_56274_row5_col4" class="data row5 col4" >0.183333</td>
#       <td id="T_56274_row5_col5" class="data row5 col5" >-0.076062</td>
#     </tr>
#     <tr>
#       <th id="T_56274_level0_row6" class="row_heading level0 row6" >Greens, 200509</th>
#       <td id="T_56274_row6_col0" class="data row6 col0" >0.378684</td>
#       <td id="T_56274_row6_col1" class="data row6 col1" >-0.003262</td>
#       <td id="T_56274_row6_col2" class="data row6 col2" >0.074042</td>
#       <td id="T_56274_row6_col3" class="data row6 col3" >-0.046300</td>
#       <td id="T_56274_row6_col4" class="data row6 col4" >0.196549</td>
#       <td id="T_56274_row6_col5" class="data row6 col5" >-0.087401</td>
#     </tr>
#     <tr>
#       <th id="T_56274_level0_row7" class="row_heading level0 row7" >Greens, 200909</th>
#       <td id="T_56274_row7_col0" class="data row7 col0" >0.380871</td>
#       <td id="T_56274_row7_col1" class="data row7 col1" >-0.103994</td>
#       <td id="T_56274_row7_col2" class="data row7 col2" >0.111328</td>
#       <td id="T_56274_row7_col3" class="data row7 col3" >0.007176</td>
#       <td id="T_56274_row7_col4" class="data row7 col4" >0.241080</td>
#       <td id="T_56274_row7_col5" class="data row7 col5" >0.009873</td>
#     </tr>
#     <tr>
#       <th id="T_56274_level0_row8" class="row_heading level0 row8" >Greens, 201309</th>
#       <td id="T_56274_row8_col0" class="data row8 col0" >0.454915</td>
#       <td id="T_56274_row8_col1" class="data row8 col1" >-0.076593</td>
#       <td id="T_56274_row8_col2" class="data row8 col2" >0.057747</td>
#       <td id="T_56274_row8_col3" class="data row8 col3" >0.023493</td>
#       <td id="T_56274_row8_col4" class="data row8 col4" >0.188924</td>
#       <td id="T_56274_row8_col5" class="data row8 col5" >0.055849</td>
#     </tr>
#     <tr>
#       <th id="T_56274_level0_row9" class="row_heading level0 row9" >Greens, 201709</th>
#       <td id="T_56274_row9_col0" class="data row9 col0" >0.438377</td>
#       <td id="T_56274_row9_col1" class="data row9 col1" >-0.117955</td>
#       <td id="T_56274_row9_col2" class="data row9 col2" >0.018862</td>
#       <td id="T_56274_row9_col3" class="data row9 col3" >0.014365</td>
#       <td id="T_56274_row9_col4" class="data row9 col4" >0.239478</td>
#       <td id="T_56274_row9_col5" class="data row9 col5" >0.095390</td>
#     </tr>
#     <tr>
#       <th id="T_56274_level0_row10" class="row_heading level0 row10" >Greens, 202109</th>
#       <td id="T_56274_row10_col0" class="data row10 col0" >0.446451</td>
#       <td id="T_56274_row10_col1" class="data row10 col1" >-0.084075</td>
#       <td id="T_56274_row10_col2" class="data row10 col2" >-0.099718</td>
#       <td id="T_56274_row10_col3" class="data row10 col3" >0.090621</td>
#       <td id="T_56274_row10_col4" class="data row10 col4" >0.054381</td>
#       <td id="T_56274_row10_col5" class="data row10 col5" >0.172478</td>
#     </tr>
#   </tbody>
# </table>

# %%
svd_topic_vectors_df.loc[lefts].style.applymap(color)
# Out:
# <style type="text/css">
# #T_a05c1_row0_col0, #T_a05c1_row0_col1, #T_a05c1_row0_col3, #T_a05c1_row0_col4, #T_a05c1_row0_col5, #T_a05c1_row1_col0, #T_a05c1_row1_col1, #T_a05c1_row1_col3, #T_a05c1_row1_col4, #T_a05c1_row1_col5, #T_a05c1_row2_col0, #T_a05c1_row2_col1, #T_a05c1_row2_col3, #T_a05c1_row2_col4, #T_a05c1_row2_col5, #T_a05c1_row3_col1, #T_a05c1_row3_col3, #T_a05c1_row3_col4, #T_a05c1_row3_col5, #T_a05c1_row4_col1, #T_a05c1_row4_col3, #T_a05c1_row4_col4, #T_a05c1_row4_col5, #T_a05c1_row5_col1, #T_a05c1_row5_col3, #T_a05c1_row5_col4, #T_a05c1_row6_col1, #T_a05c1_row6_col3, #T_a05c1_row6_col4, #T_a05c1_row7_col1, #T_a05c1_row7_col3, #T_a05c1_row7_col4, #T_a05c1_row8_col1, #T_a05c1_row8_col3, #T_a05c1_row8_col4 {
#   background-color: 0;
# }
# #T_a05c1_row0_col2, #T_a05c1_row1_col2, #T_a05c1_row2_col2, #T_a05c1_row3_col0, #T_a05c1_row3_col2, #T_a05c1_row4_col0, #T_a05c1_row4_col2, #T_a05c1_row5_col0, #T_a05c1_row5_col2, #T_a05c1_row5_col5, #T_a05c1_row6_col0, #T_a05c1_row6_col2, #T_a05c1_row6_col5, #T_a05c1_row7_col0, #T_a05c1_row7_col2, #T_a05c1_row7_col5, #T_a05c1_row8_col0, #T_a05c1_row8_col2, #T_a05c1_row8_col5 {
#   background-color: peachpuff;
# }
# </style>
# <table id="T_a05c1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a05c1_level0_col0" class="col_heading level0 col0" >topic0</th>
#       <th id="T_a05c1_level0_col1" class="col_heading level0 col1" >topic1</th>
#       <th id="T_a05c1_level0_col2" class="col_heading level0 col2" >topic2</th>
#       <th id="T_a05c1_level0_col3" class="col_heading level0 col3" >topic3</th>
#       <th id="T_a05c1_level0_col4" class="col_heading level0 col4" >topic4</th>
#       <th id="T_a05c1_level0_col5" class="col_heading level0 col5" >topic5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a05c1_level0_row0" class="row_heading level0 row0" >Lefts, 199012</th>
#       <td id="T_a05c1_row0_col0" class="data row0 col0" >-0.023965</td>
#       <td id="T_a05c1_row0_col1" class="data row0 col1" >-0.288039</td>
#       <td id="T_a05c1_row0_col2" class="data row0 col2" >0.360324</td>
#       <td id="T_a05c1_row0_col3" class="data row0 col3" >-0.000319</td>
#       <td id="T_a05c1_row0_col4" class="data row0 col4" >-0.330633</td>
#       <td id="T_a05c1_row0_col5" class="data row0 col5" >-0.128732</td>
#     </tr>
#     <tr>
#       <th id="T_a05c1_level0_row1" class="row_heading level0 row1" >Lefts, 199410</th>
#       <td id="T_a05c1_row1_col0" class="data row1 col0" >0.028277</td>
#       <td id="T_a05c1_row1_col1" class="data row1 col1" >-0.151221</td>
#       <td id="T_a05c1_row1_col2" class="data row1 col2" >0.404060</td>
#       <td id="T_a05c1_row1_col3" class="data row1 col3" >-0.040288</td>
#       <td id="T_a05c1_row1_col4" class="data row1 col4" >-0.211984</td>
#       <td id="T_a05c1_row1_col5" class="data row1 col5" >-0.198603</td>
#     </tr>
#     <tr>
#       <th id="T_a05c1_level0_row2" class="row_heading level0 row2" >Lefts, 199809</th>
#       <td id="T_a05c1_row2_col0" class="data row2 col0" >0.024705</td>
#       <td id="T_a05c1_row2_col1" class="data row2 col1" >-0.172066</td>
#       <td id="T_a05c1_row2_col2" class="data row2 col2" >0.390716</td>
#       <td id="T_a05c1_row2_col3" class="data row2 col3" >-0.026612</td>
#       <td id="T_a05c1_row2_col4" class="data row2 col4" >-0.295079</td>
#       <td id="T_a05c1_row2_col5" class="data row2 col5" >-0.260652</td>
#     </tr>
#     <tr>
#       <th id="T_a05c1_level0_row3" class="row_heading level0 row3" >Lefts, 200209</th>
#       <td id="T_a05c1_row3_col0" class="data row3 col0" >0.176434</td>
#       <td id="T_a05c1_row3_col1" class="data row3 col1" >-0.166197</td>
#       <td id="T_a05c1_row3_col2" class="data row3 col2" >0.241454</td>
#       <td id="T_a05c1_row3_col3" class="data row3 col3" >-0.056446</td>
#       <td id="T_a05c1_row3_col4" class="data row3 col4" >-0.282034</td>
#       <td id="T_a05c1_row3_col5" class="data row3 col5" >-0.232042</td>
#     </tr>
#     <tr>
#       <th id="T_a05c1_level0_row4" class="row_heading level0 row4" >Lefts, 200509</th>
#       <td id="T_a05c1_row4_col0" class="data row4 col0" >0.170221</td>
#       <td id="T_a05c1_row4_col1" class="data row4 col1" >-0.201493</td>
#       <td id="T_a05c1_row4_col2" class="data row4 col2" >0.215458</td>
#       <td id="T_a05c1_row4_col3" class="data row4 col3" >-0.047521</td>
#       <td id="T_a05c1_row4_col4" class="data row4 col4" >-0.215991</td>
#       <td id="T_a05c1_row4_col5" class="data row4 col5" >-0.206111</td>
#     </tr>
#     <tr>
#       <th id="T_a05c1_level0_row5" class="row_heading level0 row5" >Lefts, 200909</th>
#       <td id="T_a05c1_row5_col0" class="data row5 col0" >0.276855</td>
#       <td id="T_a05c1_row5_col1" class="data row5 col1" >-0.226897</td>
#       <td id="T_a05c1_row5_col2" class="data row5 col2" >0.206028</td>
#       <td id="T_a05c1_row5_col3" class="data row5 col3" >-0.006427</td>
#       <td id="T_a05c1_row5_col4" class="data row5 col4" >-0.250379</td>
#       <td id="T_a05c1_row5_col5" class="data row5 col5" >0.108715</td>
#     </tr>
#     <tr>
#       <th id="T_a05c1_level0_row6" class="row_heading level0 row6" >Lefts, 201309</th>
#       <td id="T_a05c1_row6_col0" class="data row6 col0" >0.305373</td>
#       <td id="T_a05c1_row6_col1" class="data row6 col1" >-0.262144</td>
#       <td id="T_a05c1_row6_col2" class="data row6 col2" >0.208498</td>
#       <td id="T_a05c1_row6_col3" class="data row6 col3" >0.030452</td>
#       <td id="T_a05c1_row6_col4" class="data row6 col4" >-0.300402</td>
#       <td id="T_a05c1_row6_col5" class="data row6 col5" >0.146221</td>
#     </tr>
#     <tr>
#       <th id="T_a05c1_level0_row7" class="row_heading level0 row7" >Lefts, 201709</th>
#       <td id="T_a05c1_row7_col0" class="data row7 col0" >0.350335</td>
#       <td id="T_a05c1_row7_col1" class="data row7 col1" >-0.264470</td>
#       <td id="T_a05c1_row7_col2" class="data row7 col2" >0.174290</td>
#       <td id="T_a05c1_row7_col3" class="data row7 col3" >0.023157</td>
#       <td id="T_a05c1_row7_col4" class="data row7 col4" >-0.267093</td>
#       <td id="T_a05c1_row7_col5" class="data row7 col5" >0.180095</td>
#     </tr>
#     <tr>
#       <th id="T_a05c1_level0_row8" class="row_heading level0 row8" >Lefts, 202109</th>
#       <td id="T_a05c1_row8_col0" class="data row8 col0" >0.362956</td>
#       <td id="T_a05c1_row8_col1" class="data row8 col1" >-0.255877</td>
#       <td id="T_a05c1_row8_col2" class="data row8 col2" >0.140123</td>
#       <td id="T_a05c1_row8_col3" class="data row8 col3" >0.042415</td>
#       <td id="T_a05c1_row8_col4" class="data row8 col4" >-0.200843</td>
#       <td id="T_a05c1_row8_col5" class="data row8 col5" >0.219646</td>
#     </tr>
#   </tbody>
# </table>

# %%
svd_topic_vectors_df.loc[afd].style.applymap(color)
# Out:
# <style type="text/css">
# #T_0e893_row0_col0, #T_0e893_row0_col1, #T_0e893_row0_col2, #T_0e893_row0_col4, #T_0e893_row0_col5, #T_0e893_row1_col0, #T_0e893_row1_col1, #T_0e893_row1_col2, #T_0e893_row1_col4, #T_0e893_row1_col5, #T_0e893_row2_col0, #T_0e893_row2_col1, #T_0e893_row2_col2, #T_0e893_row2_col4, #T_0e893_row2_col5 {
#   background-color: 0;
# }
# #T_0e893_row0_col3, #T_0e893_row1_col3, #T_0e893_row2_col3 {
#   background-color: peachpuff;
# }
# </style>
# <table id="T_0e893">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0e893_level0_col0" class="col_heading level0 col0" >topic0</th>
#       <th id="T_0e893_level0_col1" class="col_heading level0 col1" >topic1</th>
#       <th id="T_0e893_level0_col2" class="col_heading level0 col2" >topic2</th>
#       <th id="T_0e893_level0_col3" class="col_heading level0 col3" >topic3</th>
#       <th id="T_0e893_level0_col4" class="col_heading level0 col4" >topic4</th>
#       <th id="T_0e893_level0_col5" class="col_heading level0 col5" >topic5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0e893_level0_row0" class="row_heading level0 row0" >AFD, 201309</th>
#       <td id="T_0e893_row0_col0" class="data row0 col0" >-0.105097</td>
#       <td id="T_0e893_row0_col1" class="data row0 col1" >-0.299689</td>
#       <td id="T_0e893_row0_col2" class="data row0 col2" >-0.165148</td>
#       <td id="T_0e893_row0_col3" class="data row0 col3" >0.157798</td>
#       <td id="T_0e893_row0_col4" class="data row0 col4" >0.011575</td>
#       <td id="T_0e893_row0_col5" class="data row0 col5" >-0.042117</td>
#     </tr>
#     <tr>
#       <th id="T_0e893_level0_row1" class="row_heading level0 row1" >AFD, 201709</th>
#       <td id="T_0e893_row1_col0" class="data row1 col0" >-0.039946</td>
#       <td id="T_0e893_row1_col1" class="data row1 col1" >-0.239583</td>
#       <td id="T_0e893_row1_col2" class="data row1 col2" >-0.170381</td>
#       <td id="T_0e893_row1_col3" class="data row1 col3" >0.151127</td>
#       <td id="T_0e893_row1_col4" class="data row1 col4" >0.020953</td>
#       <td id="T_0e893_row1_col5" class="data row1 col5" >-0.050431</td>
#     </tr>
#     <tr>
#       <th id="T_0e893_level0_row2" class="row_heading level0 row2" >AFD, 202109</th>
#       <td id="T_0e893_row2_col0" class="data row2 col0" >-0.174302</td>
#       <td id="T_0e893_row2_col1" class="data row2 col1" >-0.356465</td>
#       <td id="T_0e893_row2_col2" class="data row2 col2" >-0.144868</td>
#       <td id="T_0e893_row2_col3" class="data row2 col3" >0.189590</td>
#       <td id="T_0e893_row2_col4" class="data row2 col4" >0.051540</td>
#       <td id="T_0e893_row2_col5" class="data row2 col5" >-0.063805</td>
#     </tr>
#   </tbody>
# </table>

# %%
svd_topic_vectors_df.loc[dp].style.applymap(color)
# Out:
# <style type="text/css">
# #T_e71e8_row0_col0, #T_e71e8_row0_col1, #T_e71e8_row0_col2, #T_e71e8_row0_col4, #T_e71e8_row0_col5, #T_e71e8_row1_col0, #T_e71e8_row1_col1, #T_e71e8_row1_col2, #T_e71e8_row1_col3, #T_e71e8_row1_col4, #T_e71e8_row1_col5, #T_e71e8_row2_col0, #T_e71e8_row2_col1, #T_e71e8_row2_col2, #T_e71e8_row2_col3, #T_e71e8_row2_col4, #T_e71e8_row2_col5 {
#   background-color: 0;
# }
# #T_e71e8_row0_col3 {
#   background-color: peachpuff;
# }
# </style>
# <table id="T_e71e8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e71e8_level0_col0" class="col_heading level0 col0" >topic0</th>
#       <th id="T_e71e8_level0_col1" class="col_heading level0 col1" >topic1</th>
#       <th id="T_e71e8_level0_col2" class="col_heading level0 col2" >topic2</th>
#       <th id="T_e71e8_level0_col3" class="col_heading level0 col3" >topic3</th>
#       <th id="T_e71e8_level0_col4" class="col_heading level0 col4" >topic4</th>
#       <th id="T_e71e8_level0_col5" class="col_heading level0 col5" >topic5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e71e8_level0_row0" class="row_heading level0 row0" >DP, 194908</th>
#       <td id="T_e71e8_row0_col0" class="data row0 col0" >-0.329732</td>
#       <td id="T_e71e8_row0_col1" class="data row0 col1" >-0.361448</td>
#       <td id="T_e71e8_row0_col2" class="data row0 col2" >-0.056242</td>
#       <td id="T_e71e8_row0_col3" class="data row0 col3" >0.131652</td>
#       <td id="T_e71e8_row0_col4" class="data row0 col4" >0.022065</td>
#       <td id="T_e71e8_row0_col5" class="data row0 col5" >-0.074925</td>
#     </tr>
#     <tr>
#       <th id="T_e71e8_level0_row1" class="row_heading level0 row1" >DP, 195309</th>
#       <td id="T_e71e8_row1_col0" class="data row1 col0" >-0.342716</td>
#       <td id="T_e71e8_row1_col1" class="data row1 col1" >-0.191646</td>
#       <td id="T_e71e8_row1_col2" class="data row1 col2" >-0.059746</td>
#       <td id="T_e71e8_row1_col3" class="data row1 col3" >0.080210</td>
#       <td id="T_e71e8_row1_col4" class="data row1 col4" >0.065475</td>
#       <td id="T_e71e8_row1_col5" class="data row1 col5" >0.022693</td>
#     </tr>
#     <tr>
#       <th id="T_e71e8_level0_row2" class="row_heading level0 row2" >DP, 195709</th>
#       <td id="T_e71e8_row2_col0" class="data row2 col0" >-0.385395</td>
#       <td id="T_e71e8_row2_col1" class="data row2 col1" >-0.100090</td>
#       <td id="T_e71e8_row2_col2" class="data row2 col2" >-0.056786</td>
#       <td id="T_e71e8_row2_col3" class="data row2 col3" >0.073827</td>
#       <td id="T_e71e8_row2_col4" class="data row2 col4" >0.067488</td>
#       <td id="T_e71e8_row2_col5" class="data row2 col5" >0.047589</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Conclusion**
#
# The topics are generally difficult to interpret because the combinations of terms seem very random. And increasing or decreasing the number of topics doesn't help either since the topics stay the same; only new topics are added.
#
#
# Nevertheless, we can see some patterns in the data:
#
# The 'older' parties that have been around since 1949 (CDU, SPD, FDP) all score well in topic 0 and 1, but the SPD also reaches high values in topic 2 and 5, and the FDP especially in topic 3.
#
# The Greens score well in topic 4 (alongside topic 0 and 2), making them the only party to score above 0.09 in this topic. The Lefts score high in topic 0, 2 and 5.
#
# The right-wing parties AFD and DP both score highest in topic 3.

# %% [markdown]
# -----
# # LDA

# %%
#We calculate LDA on the Bag Of Words
count_vectoriser = CountVectorizer(tokenizer=my_tokeniser)
bag_of_words = count_vectoriser.fit_transform(df['text'])
vocab = count_vectoriser.get_feature_names_out()

print(bag_of_words.todense().shape)
# Out:
# (86, 55414)

# %%
#How many topics?
num_topics = 8
pd.options.display.max_columns=num_topics
labels = ['topic{}'.format(i) for i in range(num_topics)]

# %%
#LDA
lda = LatentDirichletAllocation(n_components=num_topics,
                                random_state=123,
                                learning_method='batch')

# %%
lda_topics = lda.fit_transform(bag_of_words)

# %%
#Most relevant tokens for each topic
for i, topic in enumerate(lda.components_):
    print("topic " + str(i) + ":")
    #Get last n tokens (highest values)
    print(vocab[topic.argsort()[-num_terms:]])
# Out:
# topic 0:
# ['corona' 'abschaffung' 'euro' 'beenden' '12' 'kind' 'national' 'ezb'
#  'staatlich' 'staat' 'bürger' 'lehnen' 'familie' 'eu' 'müsse' 'über'
#  'deutschland' 'deutsch' 'afd' 'für']
# topic 1:
# ['regierung' 'staat' 'politik' 'freiheit' 'gemeinde' 'wirtschaftlich'
#  'müssen' 'bundesrepublik' 'bund' 'politisch' 'sozial' 'partei' 'groß'
#  'aufgabe' 'sozialdemokratisch' 'land' 'deutschland' 'bundesregierung'
#  'volk' 'deutsch']
# topic 2:
# ['frau' 'gesellschaft' 'wirtschaft' 'deutschland' 'freiheit' 'europäisch'
#  'öffentlich' 'bundesrepublik' 'ziel' 'wirtschaftlich' 'jahr' 'bürger'
#  'politisch' 'politik' 'mensch' 'deutsch' 'staat' 'land' 'sozial' 'müssen']
# topic 3:
# ['schaffen' 'gesellschaftlich' 'jahr' 'unternehmen' 'deutschland'
#  'gesellschaft' 'pds' 'euro' 'kind' 'land' 'leben' 'stark' 'demokratisch'
#  'arbeit' 'ökologisch' 'beschäftigter' 'linke' 'mensch' 'öffentlich'
#  'sozial']
# topic 4:
# ['arbeitsplatz' 'marktwirtschaftlich' 'privatisierung' 'aufgabe' 'mittel'
#  'ökologisch' 'staatlich' 'verbessern' 'hoch' 'privat' 'steuer'
#  'bundesland' 'notwendig' 'öffentlich' 'international' 'bürger'
#  'europäisch' 'staat' 'liberal' 'müssen']
# topic 5:
# ['ziel' 'jahr' 'international' 'groß' 'eu' 'fördern' 'gesellschaft'
#  'öffentlich' 'leben' 'deutschland' 'kind' 'schaffen' 'europäisch' 'frau'
#  'land' 'ökologisch' 'sozial' 'stark' 'grün' 'mensch']
# topic 6:
# ['gemeinsam' 'bürger' 'groß' 'ziel' 'staat' 'jahr' 'fördern'
#  'international' 'eu' 'europa' 'kind' 'unternehmen' 'deutsch' 'schaffen'
#  'sozial' 'europäisch' 'land' 'mensch' 'stark' 'deutschland']
# topic 7:
# ['volk' 'mark' 'groß' 'jahr' 'familie' 'christlich' 'aufgabe' 'europa'
#  'einheit' 'düsseldorf' 'welt' 'spd' 'zukunft' 'union' 'politik' 'land'
#  'deutsch' 'deutschland' 'csu' 'cdu']

# %% [markdown]
# **Translation of topics:**
#
#     topic 0:
#     ['corona' 'abolition' 'euro' 'to end smth.' '12' 'child' 'national' 'eec' 'state-owned' 'state' 'citizen'
#     'lean' 'family' 'eu' 'must' 'about' 'germany' 'deutsch' 'afd' 'for']
#     topic 1:
#     ['government' 'state' 'politics' 'freedom' 'community' 'economic' 'must' 'federal republic' 'federation'
#     'political' 'social' 'party' 'big' 'task' 'social democratic' 'country' 'germany' 'federal government'
#     'people' 'german']
#     topic 2:
#     ['woman' 'society' 'economy' 'germany' 'freedom' 'european' 'public' 'federal republic' 'goal' 'economic'
#     'year' 'citizen' 'political' 'politics' 'human' 'german' 'state' 'country' 'social' 'must']
#     topic 3:
#     ['create' 'social' 'year' 'company' 'germany' 'society' 'pds' 'euro' 'child' 'country' 'life' 'strong'
#     'democratic' 'work' 'ecological' 'employee' 'left' 'human' 'public' 'social']
#     topic 4:
#     ['job' 'market-based' 'privatisation' 'task' 'medium/means' 'ecological' 'state-owned' 'improve' 'high'
#     'private' 'tax' 'state' 'necessary' 'public' 'international' 'citizen' 'european' 'state' 'liberal' 'must']
#     topic 5:
#     ['goal' 'year' 'international' 'great' 'eu' 'promote' 'society' 'public' 'life' 'germany' 'child' 'create'
#     'european' 'woman' 'country' 'ecological' 'social' 'strong' 'green' 'human']
#     topic 6:
#     ['together' 'citizen' 'great' 'goal' 'state' 'year' 'promote' 'international' 'eu' 'europe' 'child' 'company'
#     'german' 'create' 'social' 'european' 'country' 'human' 'strong' 'germany']
#     topic 7:
#     ['people' 'mark'(I think this refers to the German mark, the currency before the euro) 'great' 'year' 'family'
#     'christian' 'task' 'europe' 'unity' 'düsseldorf' 'world' 'spd' 'future' 'union' 'politics' 'country' 'german'
#     'germany' 'csu' 'cdu']

# %%
#How much does each topic apply to each manifesto of the CDU?
lda_topic_vectors_df = pd.DataFrame(lda_topics, columns=labels, index = names)
lda_topic_vectors_df.loc[cdu].style.applymap(color)
# Out:
# <style type="text/css">
# #T_af2ef_row0_col0, #T_af2ef_row0_col1, #T_af2ef_row0_col3, #T_af2ef_row0_col4, #T_af2ef_row0_col5, #T_af2ef_row0_col6, #T_af2ef_row0_col7, #T_af2ef_row1_col0, #T_af2ef_row1_col3, #T_af2ef_row1_col4, #T_af2ef_row1_col5, #T_af2ef_row1_col6, #T_af2ef_row1_col7, #T_af2ef_row2_col0, #T_af2ef_row2_col2, #T_af2ef_row2_col3, #T_af2ef_row2_col4, #T_af2ef_row2_col5, #T_af2ef_row2_col6, #T_af2ef_row2_col7, #T_af2ef_row3_col0, #T_af2ef_row3_col3, #T_af2ef_row3_col4, #T_af2ef_row3_col5, #T_af2ef_row3_col6, #T_af2ef_row3_col7, #T_af2ef_row4_col0, #T_af2ef_row4_col1, #T_af2ef_row4_col3, #T_af2ef_row4_col4, #T_af2ef_row4_col5, #T_af2ef_row4_col6, #T_af2ef_row5_col0, #T_af2ef_row5_col1, #T_af2ef_row5_col3, #T_af2ef_row5_col4, #T_af2ef_row5_col5, #T_af2ef_row5_col7, #T_af2ef_row6_col0, #T_af2ef_row6_col3, #T_af2ef_row6_col4, #T_af2ef_row6_col5, #T_af2ef_row6_col6, #T_af2ef_row6_col7, #T_af2ef_row7_col0, #T_af2ef_row7_col3, #T_af2ef_row7_col4, #T_af2ef_row7_col5, #T_af2ef_row7_col6, #T_af2ef_row7_col7, #T_af2ef_row8_col0, #T_af2ef_row8_col1, #T_af2ef_row8_col3, #T_af2ef_row8_col4, #T_af2ef_row8_col5, #T_af2ef_row8_col6, #T_af2ef_row9_col0, #T_af2ef_row9_col1, #T_af2ef_row9_col3, #T_af2ef_row9_col4, #T_af2ef_row9_col5, #T_af2ef_row9_col6, #T_af2ef_row9_col7, #T_af2ef_row10_col0, #T_af2ef_row10_col1, #T_af2ef_row10_col3, #T_af2ef_row10_col4, #T_af2ef_row10_col6, #T_af2ef_row10_col7, #T_af2ef_row11_col0, #T_af2ef_row11_col1, #T_af2ef_row11_col3, #T_af2ef_row11_col4, #T_af2ef_row11_col5, #T_af2ef_row11_col7, #T_af2ef_row12_col0, #T_af2ef_row12_col1, #T_af2ef_row12_col3, #T_af2ef_row12_col4, #T_af2ef_row12_col5, #T_af2ef_row13_col0, #T_af2ef_row13_col1, #T_af2ef_row13_col3, #T_af2ef_row13_col4, #T_af2ef_row13_col5, #T_af2ef_row14_col0, #T_af2ef_row14_col1, #T_af2ef_row14_col2, #T_af2ef_row14_col3, #T_af2ef_row14_col4, #T_af2ef_row14_col5, #T_af2ef_row14_col7, #T_af2ef_row15_col0, #T_af2ef_row15_col1, #T_af2ef_row15_col2, #T_af2ef_row15_col3, #T_af2ef_row15_col4, #T_af2ef_row15_col5, #T_af2ef_row15_col7, #T_af2ef_row16_col0, #T_af2ef_row16_col1, #T_af2ef_row16_col2, #T_af2ef_row16_col3, #T_af2ef_row16_col4, #T_af2ef_row16_col7, #T_af2ef_row17_col0, #T_af2ef_row17_col1, #T_af2ef_row17_col2, #T_af2ef_row17_col3, #T_af2ef_row17_col4, #T_af2ef_row17_col7, #T_af2ef_row18_col0, #T_af2ef_row18_col1, #T_af2ef_row18_col2, #T_af2ef_row18_col3, #T_af2ef_row18_col4, #T_af2ef_row18_col5, #T_af2ef_row18_col7, #T_af2ef_row19_col0, #T_af2ef_row19_col1, #T_af2ef_row19_col2, #T_af2ef_row19_col3, #T_af2ef_row19_col4, #T_af2ef_row19_col5, #T_af2ef_row19_col7 {
#   background-color: 0;
# }
# #T_af2ef_row0_col2, #T_af2ef_row1_col1, #T_af2ef_row1_col2, #T_af2ef_row2_col1, #T_af2ef_row3_col1, #T_af2ef_row3_col2, #T_af2ef_row4_col2, #T_af2ef_row4_col7, #T_af2ef_row5_col2, #T_af2ef_row5_col6, #T_af2ef_row6_col1, #T_af2ef_row6_col2, #T_af2ef_row7_col1, #T_af2ef_row7_col2, #T_af2ef_row8_col2, #T_af2ef_row8_col7, #T_af2ef_row9_col2, #T_af2ef_row10_col2, #T_af2ef_row10_col5, #T_af2ef_row11_col2, #T_af2ef_row11_col6, #T_af2ef_row12_col2, #T_af2ef_row12_col6, #T_af2ef_row12_col7, #T_af2ef_row13_col2, #T_af2ef_row13_col6, #T_af2ef_row13_col7, #T_af2ef_row14_col6, #T_af2ef_row15_col6, #T_af2ef_row16_col5, #T_af2ef_row16_col6, #T_af2ef_row17_col5, #T_af2ef_row17_col6, #T_af2ef_row18_col6, #T_af2ef_row19_col6 {
#   background-color: peachpuff;
# }
# </style>
# <table id="T_af2ef">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_af2ef_level0_col0" class="col_heading level0 col0" >topic0</th>
#       <th id="T_af2ef_level0_col1" class="col_heading level0 col1" >topic1</th>
#       <th id="T_af2ef_level0_col2" class="col_heading level0 col2" >topic2</th>
#       <th id="T_af2ef_level0_col3" class="col_heading level0 col3" >topic3</th>
#       <th id="T_af2ef_level0_col4" class="col_heading level0 col4" >topic4</th>
#       <th id="T_af2ef_level0_col5" class="col_heading level0 col5" >topic5</th>
#       <th id="T_af2ef_level0_col6" class="col_heading level0 col6" >topic6</th>
#       <th id="T_af2ef_level0_col7" class="col_heading level0 col7" >topic7</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_af2ef_level0_row0" class="row_heading level0 row0" >CDU, 194908</th>
#       <td id="T_af2ef_row0_col0" class="data row0 col0" >0.000038</td>
#       <td id="T_af2ef_row0_col1" class="data row0 col1" >0.000038</td>
#       <td id="T_af2ef_row0_col2" class="data row0 col2" >0.999733</td>
#       <td id="T_af2ef_row0_col3" class="data row0 col3" >0.000038</td>
#       <td id="T_af2ef_row0_col4" class="data row0 col4" >0.000038</td>
#       <td id="T_af2ef_row0_col5" class="data row0 col5" >0.000038</td>
#       <td id="T_af2ef_row0_col6" class="data row0 col6" >0.000038</td>
#       <td id="T_af2ef_row0_col7" class="data row0 col7" >0.000038</td>
#     </tr>
#     <tr>
#       <th id="T_af2ef_level0_row1" class="row_heading level0 row1" >CDU, 195309</th>
#       <td id="T_af2ef_row1_col0" class="data row1 col0" >0.000065</td>
#       <td id="T_af2ef_row1_col1" class="data row1 col1" >0.458442</td>
#       <td id="T_af2ef_row1_col2" class="data row1 col2" >0.541166</td>
#       <td id="T_af2ef_row1_col3" class="data row1 col3" >0.000065</td>
#       <td id="T_af2ef_row1_col4" class="data row1 col4" >0.000065</td>
#       <td id="T_af2ef_row1_col5" class="data row1 col5" >0.000065</td>
#       <td id="T_af2ef_row1_col6" class="data row1 col6" >0.000065</td>
#       <td id="T_af2ef_row1_col7" class="data row1 col7" >0.000065</td>
#     </tr>
#     <tr>
#       <th id="T_af2ef_level0_row2" class="row_heading level0 row2" >CDU, 195709</th>
#       <td id="T_af2ef_row2_col0" class="data row2 col0" >0.000448</td>
#       <td id="T_af2ef_row2_col1" class="data row2 col1" >0.996860</td>
#       <td id="T_af2ef_row2_col2" class="data row2 col2" >0.000449</td>
#       <td id="T_af2ef_row2_col3" class="data row2 col3" >0.000448</td>
#       <td id="T_af2ef_row2_col4" class="data row2 col4" >0.000448</td>
#       <td id="T_af2ef_row2_col5" class="data row2 col5" >0.000449</td>
#       <td id="T_af2ef_row2_col6" class="data row2 col6" >0.000449</td>
#       <td id="T_af2ef_row2_col7" class="data row2 col7" >0.000449</td>
#     </tr>
#     <tr>
#       <th id="T_af2ef_level0_row3" class="row_heading level0 row3" >CDU, 196109</th>
#       <td id="T_af2ef_row3_col0" class="data row3 col0" >0.000551</td>
#       <td id="T_af2ef_row3_col1" class="data row3 col1" >0.740699</td>
#       <td id="T_af2ef_row3_col2" class="data row3 col2" >0.255993</td>
#       <td id="T_af2ef_row3_col3" class="data row3 col3" >0.000551</td>
#       <td id="T_af2ef_row3_col4" class="data row3 col4" >0.000551</td>
#       <td id="T_af2ef_row3_col5" class="data row3 col5" >0.000551</td>
#       <td id="T_af2ef_row3_col6" class="data row3 col6" >0.000552</td>
#       <td id="T_af2ef_row3_col7" class="data row3 col7" >0.000552</td>
#     </tr>
#     <tr>
#       <th id="T_af2ef_level0_row4" class="row_heading level0 row4" >CDU, 196509</th>
#       <td id="T_af2ef_row4_col0" class="data row4 col0" >0.000026</td>
#       <td id="T_af2ef_row4_col1" class="data row4 col1" >0.000026</td>
#       <td id="T_af2ef_row4_col2" class="data row4 col2" >0.423323</td>
#       <td id="T_af2ef_row4_col3" class="data row4 col3" >0.000026</td>
#       <td id="T_af2ef_row4_col4" class="data row4 col4" >0.000026</td>
#       <td id="T_af2ef_row4_col5" class="data row4 col5" >0.000026</td>
#       <td id="T_af2ef_row4_col6" class="data row4 col6" >0.000026</td>
#       <td id="T_af2ef_row4_col7" class="data row4 col7" >0.576521</td>
#     </tr>
#     <tr>
#       <th id="T_af2ef_level0_row5" class="row_heading level0 row5" >CDU, 196909</th>
#       <td id="T_af2ef_row5_col0" class="data row5 col0" >0.000104</td>
#       <td id="T_af2ef_row5_col1" class="data row5 col1" >0.080288</td>
#       <td id="T_af2ef_row5_col2" class="data row5 col2" >0.660709</td>
#       <td id="T_af2ef_row5_col3" class="data row5 col3" >0.000104</td>
#       <td id="T_af2ef_row5_col4" class="data row5 col4" >0.000104</td>
#       <td id="T_af2ef_row5_col5" class="data row5 col5" >0.0001

# %%
lda_topic_vectors_df.loc[spd].style.applymap(color)
# Out:
# <style type="text/css">
# #T_dda01_row0_col0, #T_dda01_row0_col3, #T_dda01_row0_col4, #T_dda01_row0_col5, #T_dda01_row0_col6, #T_dda01_row0_col7, #T_dda01_row1_col0, #T_dda01_row1_col2, #T_dda01_row1_col3, #T_dda01_row1_col4, #T_dda01_row1_col5, #T_dda01_row1_col6, #T_dda01_row1_col7, #T_dda01_row2_col0, #T_dda01_row2_col3, #T_dda01_row2_col4, #T_dda01_row2_col5, #T_dda01_row2_col6, #T_dda01_row2_col7, #T_dda01_row3_col0, #T_dda01_row3_col3, #T_dda01_row3_col4, #T_dda01_row3_col5, #T_dda01_row3_col6, #T_dda01_row3_col7, #T_dda01_row4_col0, #T_dda01_row4_col3, #T_dda01_row4_col4, #T_dda01_row4_col5, #T_dda01_row4_col6, #T_dda01_row4_col7, #T_dda01_row5_col0, #T_dda01_row5_col1, #T_dda01_row5_col3, #T_dda01_row5_col4, #T_dda01_row5_col5, #T_dda01_row5_col6, #T_dda01_row5_col7, #T_dda01_row6_col0, #T_dda01_row6_col1, #T_dda01_row6_col3, #T_dda01_row6_col4, #T_dda01_row6_col5, #T_dda01_row6_col6, #T_dda01_row6_col7, #T_dda01_row7_col0, #T_dda01_row7_col1, #T_dda01_row7_col3, #T_dda01_row7_col4, #T_dda01_row7_col5, #T_dda01_row7_col6, #T_dda01_row7_col7, #T_dda01_row8_col0, #T_dda01_row8_col1, #T_dda01_row8_col3, #T_dda01_row8_col4, #T_dda01_row8_col5, #T_dda01_row8_col6, #T_dda01_row8_col7, #T_dda01_row9_col0, #T_dda01_row9_col1, #T_dda01_row9_col3, #T_dda01_row9_col4, #T_dda01_row9_col5, #T_dda01_row9_col6, #T_dda01_row9_col7, #T_dda01_row10_col0, #T_dda01_row10_col1, #T_dda01_row10_col3, #T_dda01_row10_col4, #T_dda01_row10_col5, #T_dda01_row10_col6, #T_dda01_row10_col7, #T_dda01_row11_col0, #T_dda01_row11_col1, #T_dda01_row11_col4, #T_dda01_row11_col5, #T_dda01_row11_col6, #T_dda01_row11_col7, #T_dda01_row12_col0, #T_dda01_row12_col1, #T_dda01_row12_col3, #T_dda01_row12_col4, #T_dda01_row12_col5, #T_dda01_row12_col7, #T_dda01_row13_col0, #T_dda01_row13_col1, #T_dda01_row13_col3, #T_dda01_row13_col4, #T_dda01_row13_col5, #T_dda01_row13_col7, #T_dda01_row14_col0, #T_dda01_row14_col1, #T_dda01_row14_col2, #T_dda01_row14_col3, #T_dda01_row14_col4, #T_dda01_row14_col5, #T_dda01_row14_col7, #T_dda01_row15_col0, #T_dda01_row15_col2, #T_dda01_row15_col3, #T_dda01_row15_col4, #T_dda01_row15_col5, #T_dda01_row15_col7, #T_dda01_row16_col0, #T_dda01_row16_col1, #T_dda01_row16_col2, #T_dda01_row16_col3, #T_dda01_row16_col4, #T_dda01_row16_col7, #T_dda01_row17_col0, #T_dda01_row17_col1, #T_dda01_row17_col2, #T_dda01_row17_col3, #T_dda01_row17_col4, #T_dda01_row17_col7, #T_dda01_row18_col0, #T_dda01_row18_col1, #T_dda01_row18_col2, #T_dda01_row18_col3, #T_dda01_row18_col4, #T_dda01_row18_col7, #T_dda01_row19_col0, #T_dda01_row19_col1, #T_dda01_row19_col2, #T_dda01_row19_col3, #T_dda01_row19_col4, #T_dda01_row19_col7 {
#   background-color: 0;
# }
# #T_dda01_row0_col1, #T_dda01_row0_col2, #T_dda01_row1_col1, #T_dda01_row2_col1, #T_dda01_row2_col2, #T_dda01_row3_col1, #T_dda01_row3_col2, #T_dda01_row4_col1, #T_dda01_row4_col2, #T_dda01_row5_col2, #T_dda01_row6_col2, #T_dda01_row7_col2, #T_dda01_row8_col2, #T_dda01_row9_col2, #T_dda01_row10_col2, #T_dda01_row11_col2, #T_dda01_row11_col3, #T_dda01_row12_col2, #T_dda01_row12_col6, #T_dda01_row13_col2, #T_dda01_row13_col6, #T_dda01_row14_col6, #T_dda01_row15_col1, #T_dda01_row15_col6, #T_dda01_row16_col5, #T_dda01_row16_col6, #T_dda01_row17_col5, #T_dda01_row17_col6, #T_dda01_row18_col5, #T_dda01_row18_col6, #T_dda01_row19_col5, #T_dda01_row19_col6 {
#   background-color: peachpuff;
# }
# </style>
# <table id="T_dda01">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dda01_level0_col0" class="col_heading level0 col0" >topic0</th>
#       <th id="T_dda01_level0_col1" class="col_heading level0 col1" >topic1</th>
#       <th id="T_dda01_level0_col2" class="col_heading level0 col2" >topic2</th>
#       <th id="T_dda01_level0_col3" class="col_heading level0 col3" >topic3</th>
#       <th id="T_dda01_level0_col4" class="col_heading level0 col4" >topic4</th>
#       <th id="T_dda01_level0_col5" class="col_heading level0 col5" >topic5</th>
#       <th id="T_dda01_level0_col6" class="col_heading level0 col6" >topic6</th>
#       <th id="T_dda01_level0_col7" class="col_heading level0 col7" >topic7</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dda01_level0_row0" class="row_heading level0 row0" >SPD, 194908</th>
#       <td id="T_dda01_row0_col0" class="data row0 col0" >0.000133</td>
#       <td id="T_dda01_row0_col1" class="data row0 col1" >0.878029</td>
#       <td id="T_dda01_row0_col2" class="data row0 col2" >0.121173</td>
#       <td id="T_dda01_row0_col3" class="data row0 col3" >0.000133</td>
#       <td id="T_dda01_row0_col4" class="data row0 col4" >0.000133</td>
#       <td id="T_dda01_row0_col5" class="data row0 col5" >0.000133</td>
#       <td id="T_dda01_row0_col6" class="data row0 col6" >0.000133</td>
#       <td id="T_dda01_row0_col7" class="data row0 col7" >0.000133</td>
#     </tr>
#     <tr>
#       <th id="T_dda01_level0_row1" class="row_heading level0 row1" >SPD, 195309</th>
#       <td id="T_dda01_row1_col0" class="data row1 col0" >0.000057</td>
#       <td id="T_dda01_row1_col1" class="data row1 col1" >0.966968</td>
#       <td id="T_dda01_row1_col2" class="data row1 col2" >0.032690</td>
#       <td id="T_dda01_row1_col3" class="data row1 col3" >0.000057</td>
#       <td id="T_dda01_row1_col4" class="data row1 col4" >0.000057</td>
#       <td id="T_dda01_row1_col5" class="data row1 col5" >0.000057</td>
#       <td id="T_dda01_row1_col6" class="data row1 col6" >0.000057</td>
#       <td id="T_dda01_row1_col7" class="data row1 col7" >0.000057</td>
#     </tr>
#     <tr>
#       <th id="T_dda01_level0_row2" class="row_heading level0 row2" >SPD, 195709</th>
#       <td id="T_dda01_row2_col0" class="data row2 col0" >0.000098</td>
#       <td id="T_dda01_row2_col1" class="data row2 col1" >0.129510</td>
#       <td id="T_dda01_row2_col2" class="data row2 col2" >0.869900</td>
#       <td id="T_dda01_row2_col3" class="data row2 col3" >0.000098</td>
#       <td id="T_dda01_row2_col4" class="data row2 col4" >0.000098</td>
#       <td id="T_dda01_row2_col5" class="data row2 col5" >0.000098</td>
#       <td id="T_dda01_row2_col6" class="data row2 col6" >0.000098</td>
#       <td id="T_dda01_row2_col7" class="data row2 col7" >0.000098</td>
#     </tr>
#     <tr>
#       <th id="T_dda01_level0_row3" class="row_heading level0 row3" >SPD, 196109</th>
#       <td id="T_dda01_row3_col0" class="data row3 col0" >0.000041</td>
#       <td id="T_dda01_row3_col1" class="data row3 col1" >0.865705</td>
#       <td id="T_dda01_row3_col2" class="data row3 col2" >0.134050</td>
#       <td id="T_dda01_row3_col3" class="data row3 col3" >0.000041</td>
#       <td id="T_dda01_row3_col4" class="data row3 col4" >0.000041</td>
#       <td id="T_dda01_row3_col5" class="data row3 col5" >0.000041</td>
#       <td id="T_dda01_row3_col6" class="data row3 col6" >0.000041</td>
#       <td id="T_dda01_row3_col7" class="data row3 col7" >0.000041</td>
#     </tr>
#     <tr>
#       <th id="T_dda01_level0_row4" class="row_heading level0 row4" >SPD, 196509</th>
#       <td id="T_dda01_row4_col0" class="data row4 col0" >0.000010</td>
#       <td id="T_dda01_row4_col1" class="data row4 col1" >0.754414</td>
#       <td id="T_dda01_row4_col2" class="data row4 col2" >0.245523</td>
#       <td id="T_dda01_row4_col3" class="data row4 col3" >0.000010</td>
#       <td id="T_dda01_row4_col4" class="data row4 col4" >0.000010</td>
#       <td id="T_dda01_row4_col5" class="data row4 col5" >0.000010</td>
#       <td id="T_dda01_row4_col6" class="data row4 col6" >0.000010</td>
#       <td id="T_dda01_row4_col7" class="data row4 col7" >0.000010</td>
#     </tr>
#     <tr>
#       <th id="T_dda01_level0_row5" class="row_heading level0 row5" >SPD, 196909</th>
#       <td id="T_dda01_row5_col0" class="data row5 col0" >0.000075</td>
#       <td id="T_dda01_row5_col1" class="data row5 col1" >0.000075</td>
#       <td id="T_dda01_row5_col2" class="data row5 col2" >0.999476</td>
#       <td id="T_dda01_row5_col3" class="data row5 col3" >0.000075</td>
#       <td id="T_dda01_row5_col4" class="data row5 col4" >0.000075</td>
#       <td id="T_dda01_row5_col5" class="data row5 col5" >0.0000

# %%
lda_topic_vectors_df.loc[fdp].style.applymap(color)
# Out:
# <style type="text/css">
# #T_ec68a_row0_col0, #T_ec68a_row0_col1, #T_ec68a_row0_col3, #T_ec68a_row0_col4, #T_ec68a_row0_col5, #T_ec68a_row0_col6, #T_ec68a_row0_col7, #T_ec68a_row1_col0, #T_ec68a_row1_col3, #T_ec68a_row1_col4, #T_ec68a_row1_col5, #T_ec68a_row1_col6, #T_ec68a_row1_col7, #T_ec68a_row2_col0, #T_ec68a_row2_col3, #T_ec68a_row2_col4, #T_ec68a_row2_col5, #T_ec68a_row2_col6, #T_ec68a_row2_col7, #T_ec68a_row3_col0, #T_ec68a_row3_col3, #T_ec68a_row3_col4, #T_ec68a_row3_col5, #T_ec68a_row3_col6, #T_ec68a_row3_col7, #T_ec68a_row4_col0, #T_ec68a_row4_col4, #T_ec68a_row4_col5, #T_ec68a_row4_col6, #T_ec68a_row4_col7, #T_ec68a_row5_col0, #T_ec68a_row5_col1, #T_ec68a_row5_col3, #T_ec68a_row5_col5, #T_ec68a_row5_col6, #T_ec68a_row5_col7, #T_ec68a_row6_col0, #T_ec68a_row6_col1, #T_ec68a_row6_col3, #T_ec68a_row6_col4, #T_ec68a_row6_col5, #T_ec68a_row6_col6, #T_ec68a_row6_col7, #T_ec68a_row7_col0, #T_ec68a_row7_col1, #T_ec68a_row7_col3, #T_ec68a_row7_col4, #T_ec68a_row7_col5, #T_ec68a_row7_col6, #T_ec68a_row7_col7, #T_ec68a_row8_col0, #T_ec68a_row8_col1, #T_ec68a_row8_col3, #T_ec68a_row8_col4, #T_ec68a_row8_col5, #T_ec68a_row8_col6, #T_ec68a_row8_col7, #T_ec68a_row9_col0, #T_ec68a_row9_col1, #T_ec68a_row9_col3, #T_ec68a_row9_col4, #T_ec68a_row9_col5, #T_ec68a_row9_col6, #T_ec68a_row9_col7, #T_ec68a_row10_col0, #T_ec68a_row10_col1, #T_ec68a_row10_col3, #T_ec68a_row10_col4, #T_ec68a_row10_col5, #T_ec68a_row10_col7, #T_ec68a_row11_col0, #T_ec68a_row11_col1, #T_ec68a_row11_col3, #T_ec68a_row11_col4, #T_ec68a_row11_col5, #T_ec68a_row11_col7, #T_ec68a_row12_col0, #T_ec68a_row12_col1, #T_ec68a_row12_col3, #T_ec68a_row12_col5, #T_ec68a_row12_col7, #T_ec68a_row13_col0, #T_ec68a_row13_col1, #T_ec68a_row13_col3, #T_ec68a_row13_col4, #T_ec68a_row13_col5, #T_ec68a_row13_col7, #T_ec68a_row14_col0, #T_ec68a_row14_col1, #T_ec68a_row14_col2, #T_ec68a_row14_col3, #T_ec68a_row14_col4, #T_ec68a_row14_col5, #T_ec68a_row14_col7, #T_ec68a_row15_col0, #T_ec68a_row15_col1, #T_ec68a_row15_col3, #T_ec68a_row15_col4, #T_ec68a_row15_col5, #T_ec68a_row15_col7, #T_ec68a_row16_col0, #T_ec68a_row16_col1, #T_ec68a_row16_col2, #T_ec68a_row16_col3, #T_ec68a_row16_col4, #T_ec68a_row16_col5, #T_ec68a_row16_col7, #T_ec68a_row17_col0, #T_ec68a_row17_col1, #T_ec68a_row17_col2, #T_ec68a_row17_col3, #T_ec68a_row17_col4, #T_ec68a_row17_col5, #T_ec68a_row17_col7, #T_ec68a_row18_col0, #T_ec68a_row18_col1, #T_ec68a_row18_col2, #T_ec68a_row18_col3, #T_ec68a_row18_col4, #T_ec68a_row18_col5, #T_ec68a_row18_col7, #T_ec68a_row19_col0, #T_ec68a_row19_col1, #T_ec68a_row19_col2, #T_ec68a_row19_col3, #T_ec68a_row19_col4, #T_ec68a_row19_col5, #T_ec68a_row19_col7 {
#   background-color: 0;
# }
# #T_ec68a_row0_col2, #T_ec68a_row1_col1, #T_ec68a_row1_col2, #T_ec68a_row2_col1, #T_ec68a_row2_col2, #T_ec68a_row3_col1, #T_ec68a_row3_col2, #T_ec68a_row4_col1, #T_ec68a_row4_col2, #T_ec68a_row4_col3, #T_ec68a_row5_col2, #T_ec68a_row5_col4, #T_ec68a_row6_col2, #T_ec68a_row7_col2, #T_ec68a_row8_col2, #T_ec68a_row9_col2, #T_ec68a_row10_col2, #T_ec68a_row10_col6, #T_ec68a_row11_col2, #T_ec68a_row11_col6, #T_ec68a_row12_col2, #T_ec68a_row12_col4, #T_ec68a_row12_col6, #T_ec68a_row13_col2, #T_ec68a_row13_col6, #T_ec68a_row14_col6, #T_ec68a_row15_col2, #T_ec68a_row15_col6, #T_ec68a_row16_col6, #T_ec68a_row17_col6, #T_ec68a_row18_col6, #T_ec68a_row19_col6 {
#   background-color: peachpuff;
# }
# </style>
# <table id="T_ec68a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ec68a_level0_col0" class="col_heading level0 col0" >topic0</th>
#       <th id="T_ec68a_level0_col1" class="col_heading level0 col1" >topic1</th>
#       <th id="T_ec68a_level0_col2" class="col_heading level0 col2" >topic2</th>
#       <th id="T_ec68a_level0_col3" class="col_heading level0 col3" >topic3</th>
#       <th id="T_ec68a_level0_col4" class="col_heading level0 col4" >topic4</th>
#       <th id="T_ec68a_level0_col5" class="col_heading level0 col5" >topic5</th>
#       <th id="T_ec68a_level0_col6" class="col_heading level0 col6" >topic6</th>
#       <th id="T_ec68a_level0_col7" class="col_heading level0 col7" >topic7</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ec68a_level0_row0" class="row_heading level0 row0" >FDP, 194908</th>
#       <td id="T_ec68a_row0_col0" class="data row0 col0" >0.000035</td>
#       <td id="T_ec68a_row0_col1" class="data row0 col1" >0.010403</td>
#       <td id="T_ec68a_row0_col2" class="data row0 col2" >0.989385</td>
#       <td id="T_ec68a_row0_col3" class="data row0 col3" >0.000035</td>
#       <td id="T_ec68a_row0_col4" class="data row0 col4" >0.000035</td>
#       <td id="T_ec68a_row0_col5" class="data row0 col5" >0.000035</td>
#       <td id="T_ec68a_row0_col6" class="data row0 col6" >0.000035</td>
#       <td id="T_ec68a_row0_col7" class="data row0 col7" >0.000035</td>
#     </tr>
#     <tr>
#       <th id="T_ec68a_level0_row1" class="row_heading level0 row1" >FDP, 195309</th>
#       <td id="T_ec68a_row1_col0" class="data row1 col0" >0.000147</td>
#       <td id="T_ec68a_row1_col1" class="data row1 col1" >0.732475</td>
#       <td id="T_ec68a_row1_col2" class="data row1 col2" >0.266644</td>
#       <td id="T_ec68a_row1_col3" class="data row1 col3" >0.000147</td>
#       <td id="T_ec68a_row1_col4" class="data row1 col4" >0.000147</td>
#       <td id="T_ec68a_row1_col5" class="data row1 col5" >0.000147</td>
#       <td id="T_ec68a_row1_col6" class="data row1 col6" >0.000147</td>
#       <td id="T_ec68a_row1_col7" class="data row1 col7" >0.000147</td>
#     </tr>
#     <tr>
#       <th id="T_ec68a_level0_row2" class="row_heading level0 row2" >FDP, 195709</th>
#       <td id="T_ec68a_row2_col0" class="data row2 col0" >0.000182</td>
#       <td id="T_ec68a_row2_col1" class="data row2 col1" >0.578907</td>
#       <td id="T_ec68a_row2_col2" class="data row2 col2" >0.420001</td>
#       <td id="T_ec68a_row2_col3" class="data row2 col3" >0.000182</td>
#       <td id="T_ec68a_row2_col4" class="data row2 col4" >0.000182</td>
#       <td id="T_ec68a_row2_col5" class="data row2 col5" >0.000182</td>
#       <td id="T_ec68a_row2_col6" class="data row2 col6" >0.000182</td>
#       <td id="T_ec68a_row2_col7" class="data row2 col7" >0.000182</td>
#     </tr>
#     <tr>
#       <th id="T_ec68a_level0_row3" class="row_heading level0 row3" >FDP, 196109</th>
#       <td id="T_ec68a_row3_col0" class="data row3 col0" >0.000100</td>
#       <td id="T_ec68a_row3_col1" class="data row3 col1" >0.581061</td>
#       <td id="T_ec68a_row3_col2" class="data row3 col2" >0.418341</td>
#       <td id="T_ec68a_row3_col3" class="data row3 col3" >0.000100</td>
#       <td id="T_ec68a_row3_col4" class="data row3 col4" >0.000100</td>
#       <td id="T_ec68a_row3_col5" class="data row3 col5" >0.000100</td>
#       <td id="T_ec68a_row3_col6" class="data row3 col6" >0.000100</td>
#       <td id="T_ec68a_row3_col7" class="data row3 col7" >0.000100</td>
#     </tr>
#     <tr>
#       <th id="T_ec68a_level0_row4" class="row_heading level0 row4" >FDP, 196509</th>
#       <td id="T_ec68a_row4_col0" class="data row4 col0" >0.000035</td>
#       <td id="T_ec68a_row4_col1" class="data row4 col1" >0.120964</td>
#       <td id="T_ec68a_row4_col2" class="data row4 col2" >0.610073</td>
#       <td id="T_ec68a_row4_col3" class="data row4 col3" >0.268787</td>
#       <td id="T_ec68a_row4_col4" class="data row4 col4" >0.000035</td>
#       <td id="T_ec68a_row4_col5" class="data row4 col5" >0.000035</td>
#       <td id="T_ec68a_row4_col6" class="data row4 col6" >0.000035</td>
#       <td id="T_ec68a_row4_col7" class="data row4 col7" >0.000035</td>
#     </tr>
#     <tr>
#       <th id="T_ec68a_level0_row5" class="row_heading level0 row5" >FDP, 196909</th>
#       <td id="T_ec68a_row5_col0" class="data row5 col0" >0.000059</td>
#       <td id="T_ec68a_row5_col1" class="data row5 col1" >0.000059</td>
#       <td id="T_ec68a_row5_col2" class="data row5 col2" >0.809721</td>
#       <td id="T_ec68a_row5_col3" class="data row5 col3" >0.000059</td>
#       <td id="T_ec68a_row5_col4" class="data row5 col4" >0.189926</td>
#       <td id="T_ec68a_row5_col5" class="data row5 col5" >0.0000

# %%
lda_topic_vectors_df.loc[greens].style.applymap(color)
# Out:
# <style type="text/css">
# #T_6e676_row0_col0, #T_6e676_row0_col1, #T_6e676_row0_col3, #T_6e676_row0_col4, #T_6e676_row0_col6, #T_6e676_row0_col7, #T_6e676_row1_col0, #T_6e676_row1_col1, #T_6e676_row1_col3, #T_6e676_row1_col4, #T_6e676_row1_col6, #T_6e676_row1_col7, #T_6e676_row2_col0, #T_6e676_row2_col1, #T_6e676_row2_col3, #T_6e676_row2_col4, #T_6e676_row2_col6, #T_6e676_row2_col7, #T_6e676_row3_col0, #T_6e676_row3_col1, #T_6e676_row3_col3, #T_6e676_row3_col4, #T_6e676_row3_col6, #T_6e676_row3_col7, #T_6e676_row4_col0, #T_6e676_row4_col1, #T_6e676_row4_col3, #T_6e676_row4_col4, #T_6e676_row4_col6, #T_6e676_row4_col7, #T_6e676_row5_col0, #T_6e676_row5_col1, #T_6e676_row5_col2, #T_6e676_row5_col3, #T_6e676_row5_col4, #T_6e676_row5_col7, #T_6e676_row6_col0, #T_6e676_row6_col1, #T_6e676_row6_col2, #T_6e676_row6_col3, #T_6e676_row6_col4, #T_6e676_row6_col7, #T_6e676_row7_col0, #T_6e676_row7_col1, #T_6e676_row7_col2, #T_6e676_row7_col3, #T_6e676_row7_col4, #T_6e676_row7_col6, #T_6e676_row7_col7, #T_6e676_row8_col0, #T_6e676_row8_col1, #T_6e676_row8_col2, #T_6e676_row8_col3, #T_6e676_row8_col4, #T_6e676_row8_col6, #T_6e676_row8_col7, #T_6e676_row9_col0, #T_6e676_row9_col1, #T_6e676_row9_col2, #T_6e676_row9_col3, #T_6e676_row9_col4, #T_6e676_row9_col6, #T_6e676_row9_col7, #T_6e676_row10_col0, #T_6e676_row10_col1, #T_6e676_row10_col2, #T_6e676_row10_col3, #T_6e676_row10_col4, #T_6e676_row10_col6, #T_6e676_row10_col7 {
#   background-color: 0;
# }
# #T_6e676_row0_col2, #T_6e676_row0_col5, #T_6e676_row1_col2, #T_6e676_row1_col5, #T_6e676_row2_col2, #T_6e676_row2_col5, #T_6e676_row3_col2, #T_6e676_row3_col5, #T_6e676_row4_col2, #T_6e676_row4_col5, #T_6e676_row5_col5, #T_6e676_row5_col6, #T_6e676_row6_col5, #T_6e676_row6_col6, #T_6e676_row7_col5, #T_6e676_row8_col5, #T_6e676_row9_col5, #T_6e676_row10_col5 {
#   background-color: peachpuff;
# }
# </style>
# <table id="T_6e676">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6e676_level0_col0" class="col_heading level0 col0" >topic0</th>
#       <th id="T_6e676_level0_col1" class="col_heading level0 col1" >topic1</th>
#       <th id="T_6e676_level0_col2" class="col_heading level0 col2" >topic2</th>
#       <th id="T_6e676_level0_col3" class="col_heading level0 col3" >topic3</th>
#       <th id="T_6e676_level0_col4" class="col_heading level0 col4" >topic4</th>
#       <th id="T_6e676_level0_col5" class="col_heading level0 col5" >topic5</th>
#       <th id="T_6e676_level0_col6" class="col_heading level0 col6" >topic6</th>
#       <th id="T_6e676_level0_col7" class="col_heading level0 col7" >topic7</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6e676_level0_row0" class="row_heading level0 row0" >Greens, 198303</th>
#       <td id="T_6e676_row0_col0" class="data row0 col0" >0.000064</td>
#       <td id="T_6e676_row0_col1" class="data row0 col1" >0.000064</td>
#       <td id="T_6e676_row0_col2" class="data row0 col2" >0.868586</td>
#       <td id="T_6e676_row0_col3" class="data row0 col3" >0.020194</td>
#       <td id="T_6e676_row0_col4" class="data row0 col4" >0.000064</td>
#       <td id="T_6e676_row0_col5" class="data row0 col5" >0.110901</td>
#       <td id="T_6e676_row0_col6" class="data row0 col6" >0.000064</td>
#       <td id="T_6e676_row0_col7" class="data row0 col7" >0.000064</td>
#     </tr>
#     <tr>
#       <th id="T_6e676_level0_row1" class="row_heading level0 row1" >Greens, 198701</th>
#       <td id="T_6e676_row1_col0" class="data row1 col0" >0.000014</td>
#       <td id="T_6e676_row1_col1" class="data row1 col1" >0.000014</td>
#       <td id="T_6e676_row1_col2" class="data row1 col2" >0.722364</td>
#       <td id="T_6e676_row1_col3" class="data row1 col3" >0.061605</td>
#       <td id="T_6e676_row1_col4" class="data row1 col4" >0.000014</td>
#       <td id="T_6e676_row1_col5" class="data row1 col5" >0.215959</td>
#       <td id="T_6e676_row1_col6" class="data row1 col6" >0.000014</td>
#       <td id="T_6e676_row1_col7" class="data row1 col7" >0.000014</td>
#     </tr>
#     <tr>
#       <th id="T_6e676_level0_row2" class="row_heading level0 row2" >Greens, 199012</th>
#       <td id="T_6e676_row2_col0" class="data row2 col0" >0.000012</td>
#       <td id="T_6e676_row2_col1" class="data row2 col1" >0.000012</td>
#       <td id="T_6e676_row2_col2" class="data row2 col2" >0.305433</td>
#       <td id="T_6e676_row2_col3" class="data row2 col3" >0.021953</td>
#       <td id="T_6e676_row2_col4" class="data row2 col4" >0.000012</td>
#       <td id="T_6e676_row2_col5" class="data row2 col5" >0.672552</td>
#       <td id="T_6e676_row2_col6" class="data row2 col6" >0.000012</td>
#       <td id="T_6e676_row2_col7" class="data row2 col7" >0.000012</td>
#     </tr>
#     <tr>
#       <th id="T_6e676_level0_row3" class="row_heading level0 row3" >Greens, 199410</th>
#       <td id="T_6e676_row3_col0" class="data row3 col0" >0.000008</td>
#       <td id="T_6e676_row3_col1" class="data row3 col1" >0.000008</td>
#       <td id="T_6e676_row3_col2" class="data row3 col2" >0.257800</td>
#       <td id="T_6e676_row3_col3" class="data row3 col3" >0.002095</td>
#       <td id="T_6e676_row3_col4" class="data row3 col4" >0.000008</td>
#       <td id="T_6e676_row3_col5" class="data row3 col5" >0.740064</td>
#       <td id="T_6e676_row3_col6" class="data row3 col6" >0.000008</td>
#       <td id="T_6e676_row3_col7" class="data row3 col7" >0.000008</td>
#     </tr>
#     <tr>
#       <th id="T_6e676_level0_row4" class="row_heading level0 row4" >Greens, 199809</th>
#       <td id="T_6e676_row4_col0" class="data row4 col0" >0.000008</td>
#       <td id="T_6e676_row4_col1" class="data row4 col1" >0.000008</td>
#       <td id="T_6e676_row4_col2" class="data row4 col2" >0.204824</td>
#       <td id="T_6e676_row4_col3" class="data row4 col3" >0.000008</td>
#       <td id="T_6e676_row4_col4" class="data row4 col4" >0.000008</td>
#       <td id="T_6e676_row4_col5" class="data row4 col5" >0.795129</td>
#       <td id="T_6e676_row4_col6" class="data row4 col6" >0.000008</td>
#       <td id="T_6e676_row4_col7" class="data row4 col7" >0.000008</td>
#     </tr>
#     <tr>
#       <th id="T_6e676_level0_row5" class="row_heading level0 row5" >Greens, 200209</th>
#       <td id="T_6e676_row5_col0" class="data row5 col0" >0.000012</td>
#       <td id="T_6e676_row5_col1" class="data row5 col1" >0.000012</td>
#       <td id="T_6e676_row5_col2" class="data row5 col2" >0.019780</td>
#       <td id="T_6e676_row5_col3" class="data row5 col3" >0.000012</td>
#       <td id="T_6e676_row5_col4" class="data row5 col4" >0.000012</td>
#       <td id="T_6e676_row5_col5" class="data row5 col5" >0.837348</td>
#       <td id="T_6e676_row5_col6" class="data row5 col6" >0.142814</td>
#       <td id="T_6e676_row5_col7" class="data row5 col7" >0.000012</td>
#     </tr>
#     <tr>
#       <th id="T_6e676_level0_row6" class="row_heading level0 row6" >Greens, 200509</th>
#       <td id="T_6e676_row6_col0" class="data row6 col0" >0.000010</td>
#       <td id="T_6e676_row6_col1" class="data row6 col1" >0.000010</td>
#       <td id="T_6e676_row6_col2" class="data row6 col2" >0.001963</td>
#       <td id="T_6e676_row6_col3" class="data row6 col3" >0.000010</td>
#       <td id="T_6e676_row6_col4" class="data row6 col4" >0.000010</td>
#       <td id="T_6e676_row6_col5" class="data row6 col5" >0.833168</td>
#       <td id="T_6e676_row6_col6" class="data row6 col6" >0.164821</td>
#       <td id="T_6e676_row6_col7" class="data row6 col7" >0.000010</td>
#     </tr>
#     <tr>
#       <th id="T_6e676_level0_row7" class="row_heading level0 row7" >Greens, 200909</th>
#       <td id="T_6e676_row7_col0" class="data row7 col0" >0.000005</td>
#       <td id="T_6e676_row7_col1" class="data row7 col1" >0.000005</td>
#       <td id="T_6e676_row7_col2" class="data row7 col2" >0.000005</td>
#       <td id="T_6e676_row7_col3" class="data row7 col3" >0.000005</td>
#       <td id="T_6e676_row7_col4" class="data row7 col4" >0.000005</td>
#       <td id="T_6e676_row7_col5" class="data row7 col5" >0.997262</td>
#       <td id="T_6e676_row7_col6" class="data row7 col6" >0.002705</td>
#       <td id="T_6e676_row7_col7" class="data row7 col7" >0.000005

# %%
lda_topic_vectors_df.loc[lefts].style.applymap(color)
# Out:
# <style type="text/css">
# #T_a859c_row0_col0, #T_a859c_row0_col1, #T_a859c_row0_col4, #T_a859c_row0_col5, #T_a859c_row0_col6, #T_a859c_row0_col7, #T_a859c_row1_col0, #T_a859c_row1_col1, #T_a859c_row1_col4, #T_a859c_row1_col5, #T_a859c_row1_col6, #T_a859c_row1_col7, #T_a859c_row2_col0, #T_a859c_row2_col1, #T_a859c_row2_col4, #T_a859c_row2_col5, #T_a859c_row2_col6, #T_a859c_row2_col7, #T_a859c_row3_col0, #T_a859c_row3_col1, #T_a859c_row3_col4, #T_a859c_row3_col5, #T_a859c_row3_col7, #T_a859c_row4_col0, #T_a859c_row4_col1, #T_a859c_row4_col2, #T_a859c_row4_col4, #T_a859c_row4_col7, #T_a859c_row5_col0, #T_a859c_row5_col1, #T_a859c_row5_col2, #T_a859c_row5_col4, #T_a859c_row5_col7, #T_a859c_row6_col0, #T_a859c_row6_col1, #T_a859c_row6_col2, #T_a859c_row6_col4, #T_a859c_row6_col5, #T_a859c_row6_col6, #T_a859c_row6_col7, #T_a859c_row7_col0, #T_a859c_row7_col1, #T_a859c_row7_col2, #T_a859c_row7_col4, #T_a859c_row7_col5, #T_a859c_row7_col6, #T_a859c_row7_col7, #T_a859c_row8_col0, #T_a859c_row8_col1, #T_a859c_row8_col2, #T_a859c_row8_col4, #T_a859c_row8_col7 {
#   background-color: 0;
# }
# #T_a859c_row0_col2, #T_a859c_row0_col3, #T_a859c_row1_col2, #T_a859c_row1_col3, #T_a859c_row2_col2, #T_a859c_row2_col3, #T_a859c_row3_col2, #T_a859c_row3_col3, #T_a859c_row3_col6, #T_a859c_row4_col3, #T_a859c_row4_col5, #T_a859c_row4_col6, #T_a859c_row5_col3, #T_a859c_row5_col5, #T_a859c_row5_col6, #T_a859c_row6_col3, #T_a859c_row7_col3, #T_a859c_row8_col3, #T_a859c_row8_col5, #T_a859c_row8_col6 {
#   background-color: peachpuff;
# }
# </style>
# <table id="T_a859c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a859c_level0_col0" class="col_heading level0 col0" >topic0</th>
#       <th id="T_a859c_level0_col1" class="col_heading level0 col1" >topic1</th>
#       <th id="T_a859c_level0_col2" class="col_heading level0 col2" >topic2</th>
#       <th id="T_a859c_level0_col3" class="col_heading level0 col3" >topic3</th>
#       <th id="T_a859c_level0_col4" class="col_heading level0 col4" >topic4</th>
#       <th id="T_a859c_level0_col5" class="col_heading level0 col5" >topic5</th>
#       <th id="T_a859c_level0_col6" class="col_heading level0 col6" >topic6</th>
#       <th id="T_a859c_level0_col7" class="col_heading level0 col7" >topic7</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a859c_level0_row0" class="row_heading level0 row0" >Lefts, 199012</th>
#       <td id="T_a859c_row0_col0" class="data row0 col0" >0.000025</td>
#       <td id="T_a859c_row0_col1" class="data row0 col1" >0.000025</td>
#       <td id="T_a859c_row0_col2" class="data row0 col2" >0.309937</td>
#       <td id="T_a859c_row0_col3" class="data row0 col3" >0.689915</td>
#       <td id="T_a859c_row0_col4" class="data row0 col4" >0.000025</td>
#       <td id="T_a859c_row0_col5" class="data row0 col5" >0.000025</td>
#       <td id="T_a859c_row0_col6" class="data row0 col6" >0.000025</td>
#       <td id="T_a859c_row0_col7" class="data row0 col7" >0.000025</td>
#     </tr>
#     <tr>
#       <th id="T_a859c_level0_row1" class="row_heading level0 row1" >Lefts, 199410</th>
#       <td id="T_a859c_row1_col0" class="data row1 col0" >0.000031</td>
#       <td id="T_a859c_row1_col1" class="data row1 col1" >0.000031</td>
#       <td id="T_a859c_row1_col2" class="data row1 col2" >0.224936</td>
#       <td id="T_a859c_row1_col3" class="data row1 col3" >0.774876</td>
#       <td id="T_a859c_row1_col4" class="data row1 col4" >0.000031</td>
#       <td id="T_a859c_row1_col5" class="data row1 col5" >0.000031</td>
#       <td id="T_a859c_row1_col6" class="data row1 col6" >0.000031</td>
#       <td id="T_a859c_row1_col7" class="data row1 col7" >0.000031</td>
#     </tr>
#     <tr>
#       <th id="T_a859c_level0_row2" class="row_heading level0 row2" >Lefts, 199809</th>
#       <td id="T_a859c_row2_col0" class="data row2 col0" >0.000016</td>
#       <td id="T_a859c_row2_col1" class="data row2 col1" >0.000016</td>
#       <td id="T_a859c_row2_col2" class="data row2 col2" >0.255841</td>
#       <td id="T_a859c_row2_col3" class="data row2 col3" >0.744064</td>
#       <td id="T_a859c_row2_col4" class="data row2 col4" >0.000016</td>
#       <td id="T_a859c_row2_col5" class="data row2 col5" >0.000016</td>
#       <td id="T_a859c_row2_col6" class="data row2 col6" >0.000016</td>
#       <td id="T_a859c_row2_col7" class="data row2 col7" >0.000016</td>
#     </tr>
#     <tr>
#       <th id="T_a859c_level0_row3" class="row_heading level0 row3" >Lefts, 200209</th>
#       <td id="T_a859c_row3_col0" class="data row3 col0" >0.000018</td>
#       <td id="T_a859c_row3_col1" class="data row3 col1" >0.000018</td>
#       <td id="T_a859c_row3_col2" class="data row3 col2" >0.105411</td>
#       <td id="T_a859c_row3_col3" class="data row3 col3" >0.579356</td>
#       <td id="T_a859c_row3_col4" class="data row3 col4" >0.000018</td>
#       <td id="T_a859c_row3_col5" class="data row3 col5" >0.000018</td>
#       <td id="T_a859c_row3_col6" class="data row3 col6" >0.315141</td>
#       <td id="T_a859c_row3_col7" class="data row3 col7" >0.000018</td>
#     </tr>
#     <tr>
#       <th id="T_a859c_level0_row4" class="row_heading level0 row4" >Lefts, 200509</th>
#       <td id="T_a859c_row4_col0" class="data row4 col0" >0.000030</td>
#       <td id="T_a859c_row4_col1" class="data row4 col1" >0.000030</td>
#       <td id="T_a859c_row4_col2" class="data row4 col2" >0.080887</td>
#       <td id="T_a859c_row4_col3" class="data row4 col3" >0.580067</td>
#       <td id="T_a859c_row4_col4" class="data row4 col4" >0.000030</td>
#       <td id="T_a859c_row4_col5" class="data row4 col5" >0.128722</td>
#       <td id="T_a859c_row4_col6" class="data row4 col6" >0.210204</td>
#       <td id="T_a859c_row4_col7" class="data row4 col7" >0.000030</td>
#     </tr>
#     <tr>
#       <th id="T_a859c_level0_row5" class="row_heading level0 row5" >Lefts, 200909</th>
#       <td id="T_a859c_row5_col0" class="data row5 col0" >0.000012</td>
#       <td id="T_a859c_row5_col1" class="data row5 col1" >0.000012</td>
#       <td id="T_a859c_row5_col2" class="data row5 col2" >0.022936</td>
#       <td id="T_a859c_row5_col3" class="data row5 col3" >0.395606</td>
#       <td id="T_a859c_row5_col4" class="data row5 col4" >0.000012</td>
#       <td id="T_a859c_row5_col5" class="data row5 col5" >0.480363</td>
#       <td id="T_a859c_row5_col6" class="data row5 col6" >0.101046</td>
#       <td id="T_a859c_row5_col7" class="data row5 col7" >0.000012</td>
#     </tr>
#     <tr>
#       <th id="T_a859c_level0_row6" class="row_heading level0 row6" >Lefts, 201309</th>
#       <td id="T_a859c_row6_col0" class="data row6 col0" >0.000007</td>
#       <td id="T_a859c_row6_col1" class="data row6 col1" >0.000007</td>
#       <td id="T_a859c_row6_col2" class="data row6 col2" >0.000007</td>
#       <td id="T_a859c_row6_col3" class="data row6 col3" >0.964963</td>
#       <td id="T_a859c_row6_col4" class="data row6 col4" >0.000007</td>
#       <td id="T_a859c_row6_col5" class="data row6 col5" >0.000381</td>
#       <td id="T_a859c_row6_col6" class="data row6 col6" >0.034621</td>
#       <td id="T_a859c_row6_col7" class="data row6 col7" >0.000007</td>
#     </tr>
#     <tr>
#       <th id="T_a859c_level0_row7" class="row_heading level0 row7" >Lefts, 201709</th>
#       <td id="T_a859c_row7_col0" class="data row7 col0" >0.000005</td>
#       <td id="T_a859c_row7_col1" class="data row7 col1" >0.000005</td>
#       <td id="T_a859c_row7_col2" class="data row7 col2" >0.000005</td>
#       <td id="T_a859c_row7_col3" class="data row7 col3" >0.996897</td>
#       <td id="T_a859c_row7_col4" class="data row7 col4" >0.000005</td>
#       <td id="T_a859c_row7_col5" class="data row7 col5" >0.000005</td>
#       <td id="T_a859c_row7_col6" class="data row7 col6" >0.003074</td>
#       <td id="T_a859c_row7_col7" class="data row7 col7" >0.000005</td>
#     </tr>
#     <tr>
#       <th id="T_a859c_level0_row8" class="row_heading level0 row8" >Lefts, 202109</th>
#       <td id="T_a859c_row8_col0" class="data row8 col0" >0.000004</td>
#       <td id="T_a859c_row8_col1" class="data row8 col1" >0.000004</td>
#       <td id="T_a859c_row8_col2" class="data row8 col2" >0.000004</td>
#       <td i

# %%
lda_topic_vectors_df.loc[afd].style.applymap(color)
# Out:
# <style type="text/css">
# #T_aa6aa_row0_col0, #T_aa6aa_row0_col2, #T_aa6aa_row0_col3, #T_aa6aa_row0_col4, #T_aa6aa_row0_col7, #T_aa6aa_row1_col2, #T_aa6aa_row1_col3, #T_aa6aa_row1_col4, #T_aa6aa_row1_col7, #T_aa6aa_row2_col1, #T_aa6aa_row2_col2, #T_aa6aa_row2_col3, #T_aa6aa_row2_col4, #T_aa6aa_row2_col5, #T_aa6aa_row2_col7 {
#   background-color: 0;
# }
# #T_aa6aa_row0_col1, #T_aa6aa_row0_col5, #T_aa6aa_row0_col6, #T_aa6aa_row1_col0, #T_aa6aa_row1_col1, #T_aa6aa_row1_col5, #T_aa6aa_row1_col6, #T_aa6aa_row2_col0, #T_aa6aa_row2_col6 {
#   background-color: peachpuff;
# }
# </style>
# <table id="T_aa6aa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aa6aa_level0_col0" class="col_heading level0 col0" >topic0</th>
#       <th id="T_aa6aa_level0_col1" class="col_heading level0 col1" >topic1</th>
#       <th id="T_aa6aa_level0_col2" class="col_heading level0 col2" >topic2</th>
#       <th id="T_aa6aa_level0_col3" class="col_heading level0 col3" >topic3</th>
#       <th id="T_aa6aa_level0_col4" class="col_heading level0 col4" >topic4</th>
#       <th id="T_aa6aa_level0_col5" class="col_heading level0 col5" >topic5</th>
#       <th id="T_aa6aa_level0_col6" class="col_heading level0 col6" >topic6</th>
#       <th id="T_aa6aa_level0_col7" class="col_heading level0 col7" >topic7</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aa6aa_level0_row0" class="row_heading level0 row0" >AFD, 201309</th>
#       <td id="T_aa6aa_row0_col0" class="data row0 col0" >0.009179</td>
#       <td id="T_aa6aa_row0_col1" class="data row0 col1" >0.319899</td>
#       <td id="T_aa6aa_row0_col2" class="data row0 col2" >0.000321</td>
#       <td id="T_aa6aa_row0_col3" class="data row0 col3" >0.000321</td>
#       <td id="T_aa6aa_row0_col4" class="data row0 col4" >0.000321</td>
#       <td id="T_aa6aa_row0_col5" class="data row0 col5" >0.219764</td>
#       <td id="T_aa6aa_row0_col6" class="data row0 col6" >0.449875</td>
#       <td id="T_aa6aa_row0_col7" class="data row0 col7" >0.000321</td>
#     </tr>
#     <tr>
#       <th id="T_aa6aa_level0_row1" class="row_heading level0 row1" >AFD, 201709</th>
#       <td id="T_aa6aa_row1_col0" class="data row1 col0" >0.215567</td>
#       <td id="T_aa6aa_row1_col1" class="data row1 col1" >0.171846</td>
#       <td id="T_aa6aa_row1_col2" class="data row1 col2" >0.000132</td>
#       <td id="T_aa6aa_row1_col3" class="data row1 col3" >0.019395</td>
#       <td id="T_aa6aa_row1_col4" class="data row1 col4" >0.000016</td>
#       <td id="T_aa6aa_row1_col5" class="data row1 col5" >0.111014</td>
#       <td id="T_aa6aa_row1_col6" class="data row1 col6" >0.482013</td>
#       <td id="T_aa6aa_row1_col7" class="data row1 col7" >0.000016</td>
#     </tr>
#     <tr>
#       <th id="T_aa6aa_level0_row2" class="row_heading level0 row2" >AFD, 202109</th>
#       <td id="T_aa6aa_row2_col0" class="data row2 col0" >0.634989</td>
#       <td id="T_aa6aa_row2_col1" class="data row2 col1" >0.000009</td>
#       <td id="T_aa6aa_row2_col2" class="data row2 col2" >0.004396</td>
#       <td id="T_aa6aa_row2_col3" class="data row2 col3" >0.000009</td>
#       <td id="T_aa6aa_row2_col4" class="data row2 col4" >0.000009</td>
#       <td id="T_aa6aa_row2_col5" class="data row2 col5" >0.000009</td>
#       <td id="T_aa6aa_row2_col6" class="data row2 col6" >0.360569</td>
#       <td id="T_aa6aa_row2_col7" class="data row2 col7" >0.000009</td>
#     </tr>
#   </tbody>
# </table>

# %%
lda_topic_vectors_df.loc[dp].style.applymap(color)
# Out:
# <style type="text/css">
# #T_a7cf1_row0_col0, #T_a7cf1_row0_col3, #T_a7cf1_row0_col4, #T_a7cf1_row0_col5, #T_a7cf1_row0_col6, #T_a7cf1_row0_col7, #T_a7cf1_row1_col0, #T_a7cf1_row1_col3, #T_a7cf1_row1_col4, #T_a7cf1_row1_col5, #T_a7cf1_row1_col6, #T_a7cf1_row1_col7, #T_a7cf1_row2_col0, #T_a7cf1_row2_col3, #T_a7cf1_row2_col4, #T_a7cf1_row2_col5, #T_a7cf1_row2_col6, #T_a7cf1_row2_col7 {
#   background-color: 0;
# }
# #T_a7cf1_row0_col1, #T_a7cf1_row0_col2, #T_a7cf1_row1_col1, #T_a7cf1_row1_col2, #T_a7cf1_row2_col1, #T_a7cf1_row2_col2 {
#   background-color: peachpuff;
# }
# </style>
# <table id="T_a7cf1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a7cf1_level0_col0" class="col_heading level0 col0" >topic0</th>
#       <th id="T_a7cf1_level0_col1" class="col_heading level0 col1" >topic1</th>
#       <th id="T_a7cf1_level0_col2" class="col_heading level0 col2" >topic2</th>
#       <th id="T_a7cf1_level0_col3" class="col_heading level0 col3" >topic3</th>
#       <th id="T_a7cf1_level0_col4" class="col_heading level0 col4" >topic4</th>
#       <th id="T_a7cf1_level0_col5" class="col_heading level0 col5" >topic5</th>
#       <th id="T_a7cf1_level0_col6" class="col_heading level0 col6" >topic6</th>
#       <th id="T_a7cf1_level0_col7" class="col_heading level0 col7" >topic7</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a7cf1_level0_row0" class="row_heading level0 row0" >DP, 194908</th>
#       <td id="T_a7cf1_row0_col0" class="data row0 col0" >0.000687</td>
#       <td id="T_a7cf1_row0_col1" class="data row0 col1" >0.100065</td>
#       <td id="T_a7cf1_row0_col2" class="data row0 col2" >0.895810</td>
#       <td id="T_a7cf1_row0_col3" class="data row0 col3" >0.000688</td>
#       <td id="T_a7cf1_row0_col4" class="data row0 col4" >0.000687</td>
#       <td id="T_a7cf1_row0_col5" class="data row0 col5" >0.000687</td>
#       <td id="T_a7cf1_row0_col6" class="data row0 col6" >0.000687</td>
#       <td id="T_a7cf1_row0_col7" class="data row0 col7" >0.000687</td>
#     </tr>
#     <tr>
#       <th id="T_a7cf1_level0_row1" class="row_heading level0 row1" >DP, 195309</th>
#       <td id="T_a7cf1_row1_col0" class="data row1 col0" >0.000133</td>
#       <td id="T_a7cf1_row1_col1" class="data row1 col1" >0.147311</td>
#       <td id="T_a7cf1_row1_col2" class="data row1 col2" >0.851890</td>
#       <td id="T_a7cf1_row1_col3" class="data row1 col3" >0.000133</td>
#       <td id="T_a7cf1_row1_col4" class="data row1 col4" >0.000133</td>
#       <td id="T_a7cf1_row1_col5" class="data row1 col5" >0.000133</td>
#       <td id="T_a7cf1_row1_col6" class="data row1 col6" >0.000133</td>
#       <td id="T_a7cf1_row1_col7" class="data row1 col7" >0.000133</td>
#     </tr>
#     <tr>
#       <th id="T_a7cf1_level0_row2" class="row_heading level0 row2" >DP, 195709</th>
#       <td id="T_a7cf1_row2_col0" class="data row2 col0" >0.000203</td>
#       <td id="T_a7cf1_row2_col1" class="data row2 col1" >0.595173</td>
#       <td id="T_a7cf1_row2_col2" class="data row2 col2" >0.403606</td>
#       <td id="T_a7cf1_row2_col3" class="data row2 col3" >0.000204</td>
#       <td id="T_a7cf1_row2_col4" class="data row2 col4" >0.000203</td>
#       <td id="T_a7cf1_row2_col5" class="data row2 col5" >0.000204</td>
#       <td id="T_a7cf1_row2_col6" class="data row2 col6" >0.000204</td>
#       <td id="T_a7cf1_row2_col7" class="data row2 col7" >0.000203</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Conclusion**
#
# It is interesting to see that the 'older' parties that have been around since 1949 (CDU, SPD, FDP) score high on the same topics, namely 2 and 6. The results for topic 2 are high until about 1990/94, after which it shifts to topic 2. The DP party is also high in topic 2 (but also in topic 1), which fits the time period (their manifestos are from 1949-1957).
# All 'newer' parties have more or less their own topic: The Greens score high on topic 5, the Left on topic 3, and the AFD on topic 0 (but also topic 1&6).
#
# We can see similar results if we create a query searching for the party names. Since parties are likely to name themselves often in their election manifestos, this makes sense. One exception is the DP, which appears the most in topic 1, although it also had high scores for topic 2 in the previous analysis.

# %%
## I've modified this cell to use it for LDA instead of LSA

#query
topic_weights = pd.DataFrame(lda.components_.T, index=vocab, columns=labels)
df_topics = topic_weights.T["cdu spd fdp linke grün afd dp".split()]
df_topics.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_2565d_row0_col0, #T_2565d_row0_col1, #T_2565d_row0_col2, #T_2565d_row0_col4, #T_2565d_row0_col6, #T_2565d_row1_col3, #T_2565d_row1_col4, #T_2565d_row1_col5, #T_2565d_row2_col5, #T_2565d_row3_col6, #T_2565d_row4_col0, #T_2565d_row4_col1, #T_2565d_row4_col2, #T_2565d_row4_col3, #T_2565d_row4_col4, #T_2565d_row4_col5, #T_2565d_row4_col6, #T_2565d_row5_col3, #T_2565d_row5_col6, #T_2565d_row6_col5, #T_2565d_row6_col6, #T_2565d_row7_col3, #T_2565d_row7_col4, #T_2565d_row7_col5, #T_2565d_row7_col6 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_2565d_row0_col3, #T_2565d_row2_col3, #T_2565d_row3_col2, #T_2565d_row5_col5, #T_2565d_row6_col3, #T_2565d_row7_col2 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_2565d_row0_col5, #T_2565d_row1_col6, #T_2565d_row2_col1, #T_2565d_row3_col3, #T_2565d_row5_col4, #T_2565d_row6_col0, #T_2565d_row6_col2 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_2565d_row1_col0, #T_2565d_row3_col0 {
#   background-color: #f2faef;
#   color: #000000;
# }
# #T_2565d_row1_col1 {
#   background-color: #d8f0d2;
#   color: #000000;
# }
# #T_2565d_row1_col2, #T_2565d_row3_col5, #T_2565d_row5_col2 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_2565d_row2_col0 {
#   background-color: #2f984f;
#   color: #f1f1f1;
# }
# #T_2565d_row2_col2 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_2565d_row2_col4 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_2565d_row2_col6 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# #T_2565d_row3_col1 {
#   background-color: #eaf7e6;
#   color: #000000;
# }
# #T_2565d_row3_col4 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_2565d_row5_col0 {
#   background-color: #ceecc8;
#   color: #000000;
# }
# #T_2565d_row5_col1 {
#   background-color: #e8f6e3;
#   color: #000000;
# }
# #T_2565d_row6_col1 {
#   background-color: #46ae60;
#   color: #f1f1f1;
# }
# #T_2565d_row6_col4 {
#   background-color: #ebf7e7;
#   color: #000000;
# }
# #T_2565d_row7_col0 {
#   background-color: #0d7836;
#   color: #f1f1f1;
# }
# #T_2565d_row7_col1 {
#   background-color: #ddf2d8;
#   color: #000000;
# }
# </style>
# <table id="T_2565d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2565d_level0_col0" class="col_heading level0 col0" >cdu</th>
#       <th id="T_2565d_level0_col1" class="col_heading level0 col1" >spd</th>
#       <th id="T_2565d_level0_col2" class="col_heading level0 col2" >fdp</th>
#       <th id="T_2565d_level0_col3" class="col_heading level0 col3" >linke</th>
#       <th id="T_2565d_level0_col4" class="col_heading level0 col4" >grün</th>
#       <th id="T_2565d_level0_col5" class="col_heading level0 col5" >afd</th>
#       <th id="T_2565d_level0_col6" class="col_heading level0 col6" >dp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2565d_level0_row0" class="row_heading level0 row0" >topic0</th>
#       <td id="T_2565d_row0_col0" class="data row0 col0" >0.125032</td>
#       <td id="T_2565d_row0_col1" class="data row0 col1" >0.125040</td>
#       <td id="T_2565d_row0_col2" class="data row0 col2" >0.125000</td>
#       <td id="T_2565d_row0_col3" class="data row0 col3" >2.901631</td>
#       <td id="T_2565d_row0_col4" class="data row0 col4" >0.125003</td>
#       <td id="T_2565d_row0_col5" class="data row0 col5" >264.078224</td>
#       <td id="T_2565d_row0_col6" class="data row0 col6" >0.125000</td>
#     </tr>
#     <tr>
#       <th id="T_2565d_level0_row1" class="row_heading level0 row1" >topic1</th>
#       <td id="T_2565d_row1_col0" class="data row1 col0" >13.252210</td>
#       <td id="T_2565d_row1_col1" class="data row1 col1" >57.618115</td>
#       <td id="T_2565d_row1_col2" class="data row1 col2" >16.732354</td>
#       <td id="T_2565d_row1_col3" class="data row1 col3" >1.175226</td>
#       <td id="T_2565d_row1_col4" class="data row1 col4" >0.125212</td>
#       <td id="T_2565d_row1_col5" class="data row1 col5" >0.125044</td>
#       <td id="T_2565d_row1_col6" class="data row1 col6" >2.070777</td>
#     </tr>
#     <tr>
#       <th id="T_2565d_level0_row2" class="row_heading level0 row2" >topic2</th>
#       <td id="T_2565d_row2_col0" class="data row2 col0" >241.703522</td>
#       <td id="T_2565d_row2_col1" class="data row2 col1" >315.098351</td>
#       <td id="T_2565d_row2_col2" class="data row2 col2" >78.349614</td>
#       <td id="T_2565d_row2_col3" class="data row2 col3" >3.107902</td>
#       <td id="T_2565d_row2_col4" class="data row2 col4" >49.599389</td>
#       <td id="T_2565d_row2_col5" class="data row2 col5" >0.125000</td>
#       <td id="T_2565d_row2_col6" class="data row2 col6" >0.179223</td>
#     </tr>
#     <tr>
#       <th id="T_2565d_level0_row3" class="row_heading level0 row3" >topic3</th>
#       <td id="T_2565d_row3_col0" class="data row3 col0" >12.569619</td>
#       <td id="T_2565d_row3_col1" class="data row3 col1" >28.626849</td>
#       <td id="T_2565d_row3_col2" class="data row3 col2" >7.412257</td>
#       <td id="T_2565d_row3_col3" class="data row3 col3" >661.455957</td>
#       <td id="T_2565d_row3_col4" class="data row3 col4" >18.143390</td>
#       <td id="T_2565d_row3_col5" class="data row3 col5" >6.106603</td>
#       <td id="T_2565d_row3_col6" class="data row3 col6" >0.125000</td>
#     </tr>
#     <tr>
#       <th id="T_2565d_level0_row4" class="row_heading level0 row4" >topic4</th>
#       <td id="T_2565d_row4_col0" class="data row4 col0" >0.125042</td>
#       <td id="T_2565d_row4_col1" class="data row4 col1" >0.125037</td>
#       <td id="T_2565d_row4_col2" class="data row4 col2" >0.125006</td>
#       <td id="T_2565d_row4_col3" class="data row4 col3" >0.125000</td>
#       <td id="T_2565d_row4_col4" class="data row4 col4" >0.173206</td>
#       <td id="T_2565d_row4_col5" class="data row4 col5" >0.125000</td>
#       <td id="T_2565d_row4_col6" class="data row4 col6" >0.125000</td>
#     </tr>
#     <tr>
#       <th id="T_2565d_level0_row5" class="row_heading level0 row5" >topic5</th>
#       <td id="T_2565d_row5_col0" class="data row5 col0" >76.195950</td>
#       <td id="T_2565d_row5_col1" class="data row5 col1" >34.028073</td>
#       <td id="T_2565d_row5_col2" class="data row5 col2" >17.456994</td>
#       <td id="T_2565d_row5_col3" class="data row5 col3" >2.681094</td>
#       <td id="T_2565d_row5_col4" class="data row5 col4" >1474.035474</td>
#       <td id="T_2565d_row5_col5" class="data row5 col5" >1.190067</td>
#       <td id="T_2565d_row5_col6" class="data row5 col6" >0.125000</td>
#     </tr>
#     <tr>
#       <th id="T_2565d_level0_row6" class="row_heading level0 row6" >topic6</th>
#       <td id="T_2565d_row6_col0" class="data row6 col0" >347.405818</td>
#       <td id="T_2565d_row6_col1" class="data row6 col1" >192.901949</td>
#       <td id="T_2565d_row6_col2" class="data row6 col2" >775.015656</td>
#       <td id="T_2565d_row6_col3" class="data row6 col3" >6.428190</td>
#       <td id="T_2565d_row6_col4" class="data row6 col4" >121.989955</td>
#       <td id="T_2565d_row6_col5" class="data row6 col5" >0.125062</td>
#       <td id="T_2565d_row6_col6" class="data row6 col6" >0.125000</td>
#     </tr>
#     <tr>
#       <th id="T_2565d_level0_row7" class="row_heading level0 row7" >topic7</th>
#       <td id="T_2565d_row7_col0" class="data row7 col0" >286.622808</td>
#       <td id="T_2565d_row7_col1" class="data row7 col1" >50.476585</td>
#       <td id="T_2565d_row7_col2" class="data row7 col2" >4.783119</td>
#       <td id="T_2565d_row7_col3" class="data row7 col3" >0.125000</td>
#       <td id="T_2565d_row7_col4" class="data row7 col4" >0.808371</td>
#       <td id="T_2565d_row7_col5" class="data row7 col5" >0.125000</td>
#       <td id="T_2565d_row7_col6" class="data row7 col6" >0.125000</td>
#     </tr>
#   </tbody>
# </table>
